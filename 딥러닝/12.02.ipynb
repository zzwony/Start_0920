# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([1,2,3])
s
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
df = pd.DataFrame([[1,2,3], [4,5,6]])
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
df.columns = ['c1', 'c2', 'c3']

# %%
df
# Out:
#    c1  c2  c3
# 0   1   2   3
# 1   4   5   6

# %%
df.index = ['r1', 'r2']

# %%
df
# Out:
#     c1  c2  c3
# r1   1   2   3
# r2   4   5   6

# %%
df.rename(columns={'c2':'C2'})
# Out:
#     c1  C2  c3
# r1   1   2   3
# r2   4   5   6

# %%
import pydataset

# %%
mpg = pydataset.data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
# 234  midsize
#
# [234 rows x 11 columns]

# %%
mpg.iloc[::2, ::2]
# Out:
#     manufacturer  displ  cyl drv  hwy       class
# 1           audi    1.8    4   f   29     compact
# 3           audi    2.0    4   f   31     compact
# 5           audi    2.8    6   f   26     compact
# 7           audi    3.1    6   f   27     compact
# 9           audi    1.8    4   4   25     compact
# 11          audi    2.0    4   4   27     compact
# 13          audi    2.8    6   4   25     compact
# 15          audi    3.1    6   4   25     compact
# 17          audi    3.1    6   4   25     midsize
# 19     chevrolet    5.3    8   r   20         suv
# 21     chevrolet    5.3    8   r   20         suv
# 23     chevrolet    6.0    8   r   17         suv
# 25     chevrolet    5.7    8   r   23     2seater
# 27     chevrolet    6.2    8   r   25     2seater
# 29     chevrolet    5.3    8   4   19         suv
# 31     chevrolet    5.7    8   4   15         suv
# 33     chevrolet    2.4    4   f   27     midsize
# 35     chevrolet    3.1    6   f   26     midsize
# 37     chevrolet    3.6    6   f   26     midsize
# 39         dodge    3.0    6   f   24     minivan
# 41         dodge    3.3    6   f   22     minivan
# 43         dodge    3.3    6   f   24     minivan
# 45         dodge    3.8    6   f   22     minivan
# 47         dodge    3.8    6   f   23     minivan
# 49         dodge    3.7    6   4   19      pickup
# 51         dodge    3.9    6   4   17      pickup
# 53         dodge    4.7    8   4   19      pickup
# 55         dodge    4.7    8   4   12      pickup
# 57         dodge    5.2    8   4   15      pickup
# 59         dodge    4.7    8   4   17         suv
# 61         dodge    4.7    8   4   17         suv
# 63         dodge    5.7    8   4   18         suv
# 65         dodge    4.7    8   4   16      pickup
# 67         dodge    4.7    8   4   17      pickup
# 69         dodge    4.7    8   4   16      pickup
# 71         dodge    5.2    8   4   15      pickup
# 73         dodge    5.7    8   4   17      pickup
# 75          ford    4.6    8   r   17         suv
# 77          ford    5.4    8   r   18         suv
# 79          ford    4.0    6   4   19         suv
# 81          ford    4.0    6   4   19         suv
# 83          ford    5.0    8   4   17         suv
# 85          ford    4.2    6   4   17      pickup
# 87          ford    4.6    8   4   16      pickup
# 89          ford    5.4    8   4   15      pickup
# 91          ford    3.8    6   r   26  subcompact
# 93          ford    4.0    6   r   26  subcompact
# 95          ford    4.6    8   r   21  subcompact
# 97          ford    4.6    8   r   23  subcompact
# 99          ford    5.4    8   r   20  subcompact
# 101        honda    1.6    4   f   32  subcompact
# 103        honda    1.6    4   f   29  subcompact
# 105        honda    1.8    4   f   34  subcompact
# 107        honda    1.8    4   f   36  subcompact
# 109      hyundai    2.4    4   f   26     midsize
# 111      hyundai    2.4    4   f   30     midsize
# 113      hyundai    2.5    6   f   26     midsize
# 115      hyundai    3.3    6   f   28     midsize
# 117      hyundai    2.0    4   f   29  subcompact
# 119      hyundai    2.0    4   f   27  subcompact
# 121      hyundai    2.7    6   f   24  subcompact
# 123         jeep    3.0    6   4   22         suv
# 125         jeep    4.0    6   4   20         suv
# 127         jeep    4.7    8   4   12         suv
# 129         jeep    5.7    8   4   18         suv
# 131   land rover    4.0    8   4   15         suv
# 133   land rover    4.4    8   4   18         suv
# 135      lincoln    5.4    8   r   17         suv
# 137      lincoln    5.4    8   r   18         suv
# 139      mercury    4.0    6   4   19         suv
# 141      mercury    5.0    8   4   17         suv
# 143       nissan    2.4    4   f   27     compact
# 145       nissan    2.5    4   f   32     midsize
# 147       nissan    3.5    6   f   26     midsize
# 149       nissan    3.0    6   f   25     midsize
# 151       nissan    3.3    6   4   17         suv
# 153       nissan    4.0    6   4   20         suv
# 155      pontiac    3.1    6   f   26     midsize
# 157      pontiac    3.8    6   f   27     midsize
# 159      pontiac    5.3    8   f   25     midsize
# 161       subaru    2.5    4   4   24         suv
# 163       subaru    2.5    4   4   25         suv
# 165       subaru    2.5    4   4   23         suv
# 167       subaru    2.2    4   4   26  subcompact
# 169       subaru    2.5    4   4   26  subcompact
# 171       subaru    2.5    4   4   27     compact
# 173       subaru    2.5    4   4   27     compact
# 175       toyota    2.7    4   4   20         suv
# 177       toyota    3.4    6   4   17         suv
# 179       toyota    4.7    8   4   17         suv
# 181       toyota    2.2    4   f   27     midsize
# 183       toyota    2.4    4   f   31     midsize
# 185       toyota    3.0    6   f   26     midsize
# 187       toyota    2.2    4   f   27     compact
# 189       toyota    2.4    4   f   31     compact
# 191       toyota    3.0    6   f   26     compact
# 193       toyota    3.3    6   f   27     compact
# 195       toyota    1.8    4   f   33     compact
# 197       toyota    1.8    4   f   37     compact
# 199       toyota    4.7    8   4   15         suv
# 201       toyota    2.7    4   4   20      pickup
# 203       toyota    2.7    4   4   22      pickup
# 205       toyota    3.4    6   4   19      pickup
# 207       toyota    4.0    6   4   20      pickup
# 209   volkswagen    2.0    4   f   26     compact
# 211   volkswagen    2.0    4   f   29     compact
# 213   volkswagen    1.9    4   f   44     compact
# 215   volkswagen    2.0    4   f   26     compact
# 217   volkswagen    2.0    4   f   29     compact
# 219   volkswagen    2.5    5   f   29     compact
# 221   volkswagen    2.8    6   f   24     compact
# 223   volkswagen    1.9    4   f   41  subcompact
# 225   volkswagen    2.0    4   f   26  subcompact
# 227   volkswagen    2.5    5   f   29  subcompact
# 229   volkswagen    1.8    4   f   29     midsize
# 231   volkswagen    2.0    4   f   29     midsize
# 233   volkswagen    2.8    6   f   26     midsize

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
mpg['year'].astype('string')
# Out:
# 1      1999
# 2      1999
# 3      2008
# 4      2008
# 5      1999
#        ...
# 230    2008
# 231    2008
# 232    1999
# 233    1999
# 234    2008
# Name: year, Length: 234, dtype: string

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
# 234  midsize
#
# [234 rows x 11 columns]

# %%
mpg.groupby('manufacturer')['cty'].mean()
# Out:
# manufacturer
# audi          17.611111
# chevrolet     15.000000
# dodge         13.135135
# ford          14.000000
# honda         24.444444
# hyundai       18.642857
# jeep          13.500000
# land rover    11.500000
# lincoln       11.333333
# mercury       13.250000
# nissan        18.076923
# pontiac       17.000000
# subaru        19.285714
# toyota        18.529412
# volkswagen    20.925926
# Name: cty, dtype: float64

# %%
mpg[['model', 'year']]
# Out:
#       model  year
# 1        a4  1999
# 2        a4  1999
# 3        a4  2008
# 4        a4  2008
# 5        a4  1999
# ..      ...   ...
# 230  passat  2008
# 231  passat  2008
# 232  passat  1999
# 233  passat  1999
# 234  passat  2008
#
# [234 rows x 2 columns]

# %%
df = mpg.iloc[ :10, :3]
df
# Out:
#    manufacturer       model  displ
# 1          audi          a4    1.8
# 2          audi          a4    1.8
# 3          audi          a4    2.0
# 4          audi          a4    2.0
# 5          audi          a4    2.8
# 6          audi          a4    2.8
# 7          audi          a4    3.1
# 8          audi  a4 quattro    1.8
# 9          audi  a4 quattro    1.8
# 10         audi  a4 quattro    2.0

# %%
data = {
    'manufacturer' : ['hyundai'],
    'model' : ['sonata'],
    'displ' : [2.0]
}

ddf = pd.DataFrame(data)

df = pd.concat([df, ddf])

# %%
df
# Out:
#    manufacturer       model displ
# 0          audi          a4   1.8
# 1          audi          a4   1.8
# 2          audi          a4   2.0
# 3          audi          a4   2.0
# 4          audi          a4   2.8
# 5          audi          a4   2.8
# 6          audi          a4   3.1
# 7          audi  a4 quattro   1.8
# 8          audi  a4 quattro   1.8
# 9          audi  a4 quattro   2.0
# 10      hyundai      sonata   2.0
# 11      hyundai      sonata   2.0
# 0       hyundai      sonata   2.0

# %%
new = {
    'manufacturer' : 'hyundai',
    'model' : 'sonata',
    'displ' : '2.0'
}

df = df.append(new, ignore_index=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5236\2588732025.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new, ignore_index=True)

# %%
df.loc[14, :] = ['hyundai', 'sonata', 2.0]
df
# Out:
#    manufacturer       model  displ
# 1          audi          a4    1.8
# 2          audi          a4    1.8
# 3          audi          a4    2.0
# 4          audi          a4    2.0
# 5          audi          a4    2.8
# 6          audi          a4    2.8
# 7          audi          a4    3.1
# 8          audi  a4 quattro    1.8
# 9          audi  a4 quattro    1.8
# 10         audi  a4 quattro    2.0
# 14      hyundai      sonata    2.0

# %%
df= df.reset_index(drop=True)
df
# Out:
#    manufacturer       model  displ
# 0          audi          a4    1.8
# 1          audi          a4    1.8
# 2          audi          a4    2.0
# 3          audi          a4    2.0
# 4          audi          a4    2.8
# 5          audi          a4    2.8
# 6          audi          a4    3.1
# 7          audi  a4 quattro    1.8
# 8          audi  a4 quattro    1.8
# 9          audi  a4 quattro    2.0
# 10      hyundai      sonata    2.0

# %% [markdown]
# # fit 메서드에서 callbacks 매개변수 사용하기

# %%
from keras import layers
from tensorflow.keras.datasets import mnist
import keras

def get_mnist_model():
    inputs = keras.Input(shape=(28 * 28,))
    features = layers.Dense(512, activation="relu")(inputs)
    features = layers.Dropout(0.5)(features)
    outputs = layers.Dense(10, activation="softmax")(features)
    model = keras.Model(inputs, outputs)
    return model

(images, labels), (test_images, test_labels) = mnist.load_data()
images = images.reshape((60000, 28 * 28)).astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28)).astype("float32") / 255
train_images, val_images = images[10000:], images[:10000]
train_labels, val_labels = labels[10000:], labels[:10000]



###
callback_list = [
    keras.callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=2,
    ),
    keras.callbacks.ModelCheckpoint(
        filepath='checkpoint_path.keras',
        monitor='val_loss',
        save_best_only=True,
    )
]
###




model = get_mnist_model()
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
model.fit(train_images, train_labels,
          epochs=10,
          callbacks=callback_list,
          validation_data=(val_images, val_labels))
test_metrics = model.evaluate(test_images, test_labels)
predictions = model.predict(test_images)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.2937 - accuracy: 0.9114 - val_loss: 0.1502 - val_accuracy: 0.9558
# Epoch 2/10
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.1622 - accuracy: 0.9549 - val_loss: 0.1162 - val_accuracy: 0.9684
# Epoch 3/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.1378 - accuracy: 0.9633 - val_loss: 0.1134 - val_accuracy: 0.9714
# Epoch 4/10
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.1248 - accuracy: 0.9679 - val_loss: 0.1152 - val_accuracy: 0.9722
# Epoch 5/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1185 - accuracy: 0.9701 - val_loss: 0.1080 - val_accuracy: 0.9754
# Epoch 6/10
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.1108 - accuracy: 0.9730 - val_loss: 0.1130 - val_accuracy: 0.9755
# Epoch 7/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1062 - accuracy: 0.9739 - val_loss: 0.1172 - val_accuracy: 0.9762
# Epoch 8/10
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.1025 - accuracy: 0.9763 - val_loss: 0.1168 - val_accuracy: 0.9753
# Epoch 9/10
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.0979 - accuracy: 0.9775 - val_loss: 0.1281 - val_accuracy: 0.9772
# Epoch 10/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0963 - accuracy: 0.9780 - val_loss: 0.1176 - val_accuracy: 0.9777
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1045 - accuracy: 0.9793
# 313/313 [==============================] - 1s 2ms/step

# %%
model = keras.models.load_model('checkpoint_path.keras')  ##괄호 안에 있는건 파일이다.
model

# %%
model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1001 - accuracy: 0.9761
# [0.10013575851917267, 0.9761000275611877]

# %%
model.predict(test_images[:10])
# Out:
# 1/1 [==============================] - 0s 68ms/step
# array([[1.7899883e-14, 6.7546644e-21, 1.0099292e-11, 1.6862328e-08,
#         1.3248926e-20, 1.3757459e-12, 1.7738119e-24, 1.0000000e+00,
#         3.6086277e-14, 5.8077548e-10],
#        [1.4745554e-20, 4.5960729e-14, 1.0000000e+00, 1.9491852e-12,
#         0.0000000e+00, 2.2924274e-14, 1.9999503e-16, 9.1137120e-33,
#         4.7070472e-15, 1.6884270e-35],
#        [2.0237437e-11, 9.9999475e-01, 4.0662925e-07, 4.9040970e-08,
#         3.5057763e-08, 7.0141503e-08, 3.6577983e-09, 2.5063041e-06,
#         2.2016284e-06, 3.1684357e-09],
#        [9.9999225e-01, 4.1757020e-16, 4.2128968e-07, 2.4798663e-08,
#         2.1755143e-08, 1.6815195e-06, 8.0334377e-07, 1.9073566e-06,
#         9.6539676e-10, 2.9946495e-06],
#        [1.6074917e-08, 5.2932021e-14, 2.4768639e-07, 6.7513248e-09,
#         9.9915445e-01, 4.6329433e-08, 7.9307689e-08, 8.8507977e-06,
#         8.7868536e-08, 8.3615177e-04],
#        [4.9680285e-13, 9.9999666e-01, 1.4989723e-08, 2.2549886e-08,
#         1.8776847e-08, 1.5866060e-09, 2.3945249e-11, 2.5775557e-06,
#         7.3250601e-07, 1.9766169e-09],
#        [5.2065665e-16, 5.5415590e-12, 8.4381800e-11, 1.2173991e-10,
#         9.9996543e-01, 1.1597360e-09, 3.6229242e-10, 1.3853489e-08,
#         3.3985332e-05, 5.9765631e-07],
#        [4.5039399e-09, 2.2800350e-06, 1.9961959e-05, 3.2865056e-03,
#         6.1608612e-04, 1.6090392e-04, 4.3617682e-11, 2.9185269e-04,
#         5.3029824e-05, 9.9556941e-01],
#        [4.6783654e-15, 1.3472038e-20, 1.1735801e-13, 2.1026851e-14,
#         2.8790364e-12, 9.9980837e-01, 1.9162653e-04, 9.8972801e-19,
#         1.2241375e-09, 5.8291931e-09],
#        [1.2966477e-18, 5.2756533e-18, 2.1732041e-14, 4.0381969e-12,
#         2.0834643e-05, 2.3800452e-12, 3.6452605e-18, 2.8300719e-06,
#         1.0569271e-07, 9.9997616e-01]], dtype=float32)

# %% [markdown]
# # 텐서보드

# %%
model = get_mnist_model()
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
tensorboard = keras.callbacks.TensorBoard(log_dir='C:/temp')
model.fit(train_images, train_labels,
          epochs=10,
          validation_data=(val_images, val_labels),
          callbacks=[tensorboard])
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.2945 - accuracy: 0.9128 - val_loss: 0.1437 - val_accuracy: 0.9581
# Epoch 2/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.1627 - accuracy: 0.9529 - val_loss: 0.1239 - val_accuracy: 0.9673
# Epoch 3/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1364 - accuracy: 0.9628 - val_loss: 0.1176 - val_accuracy: 0.9699
# Epoch 4/10
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.1230 - accuracy: 0.9682 - val_loss: 0.1042 - val_accuracy: 0.9745
# Epoch 5/10
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.1138 - accuracy: 0.9712 - val_loss: 0.1105 - val_accuracy: 0.9747
# Epoch 6/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1082 - accuracy: 0.9737 - val_loss: 0.1064 - val_accuracy: 0.9768
# Epoch 7/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1042 - accuracy: 0.9744 - val_loss: 0.1096 - val_accuracy: 0.9787
# Epoch 8/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1040 - accuracy: 0.9760 - val_loss: 0.1132 - val_accuracy: 0.9765
# Epoch 9/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0974 - accuracy: 0.9777 - val_loss: 0.1173 - val_accuracy: 0.9761
# Epoch 10/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.0961 - accuracy: 0.9781 - val_loss: 0.1226 - val_accuracy: 0.9788

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# %tensorboard --logdir / 'C:/temp'
# Out:
# ERROR: Failed to launch TensorBoard (exited with 2).
# Contents of stderr:
# 2022-12-02 14:42:44.849901: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-12-02 14:42:44.850029: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# usage: tensorboard [-h] [--helpfull] [--logdir PATH] [--logdir_spec PATH_SPEC]
#                    [--host ADDR] [--bind_all] [--port PORT]
#                    [--reuse_port BOOL] [--load_fast {false,auto,true}]
#                    [--extra_data_server_flags EXTRA_DATA_SERVER_FLAGS]
#                    [--grpc_creds_type {local,ssl,ssl_dev}]
#                    [--grpc_data_provider PORT] [--purge_orphaned_data BOOL]
#                    [--db URI] [--db_import] [--inspect] [--version_tb]
#                    [--tag TAG] [--event_file PATH] [--path_prefix PATH]
#                    [--window_title TEXT] [--max_reload_threads COUNT]
#                    [--reload_interval SECONDS] [--reload_task TYPE]
#                    [--reload_multifile BOOL]
#                    [--reload_multifile_inactive_secs SECONDS]
#                    [--generic_data TYPE]
#                    [--samples_per_plugin SAMPLES_PER_PLUGIN]
#                    [--detect_file_replacement BOOL]
#                    [--whatif-use-unsafe-custom-prediction YOUR_CUSTOM_PREDICT_FUNCTION.py]
#                    [--whatif-data-dir PATH]
#                    {serve,dev} ...
# tensorboard: error: argument {serve,dev}: invalid choice: 'C:/temp' (choose from 'serve', 'dev')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import optimizers, Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.callbacks import Callback

import time

# %%
from sklearn.datasets import make_moons


# 데이터 생성
x, y = make_moons(n_samples=100, noise=0.2, random_state=32)


# 데이터 그림 그리기
df = pd.DataFrame(dict(x=x[:,0], y=x[:,1], label=y))
colors = {0:'red', 1:'blue'}
fig, ax = plt.subplots()
grouped = df.groupby('label')

for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
plt.show()


# 데이터 나누기
split_index = int(len(x)*0.3)
train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]

# %%
# copy from 
from IPython.display import clear_output
from tensorflow.keras.callbacks import Callback

class PlotLosses(Callback):

    def on_train_begin(self, logs={}):
        self.epochs = []
        self.losses = []
        self.val_losses = []
        self.logs = []
        self.fig = plt.figure()


    def on_epoch_end(self, epoch, logs={}):
        self.epochs.append(epoch)
        self.losses.append(logs.get('loss'))
        self.val_losses.append(logs.get('val_loss'))

        clear_output(wait=True)
        plt.plot(self.epochs, self.losses, label="loss")
        plt.plot(self.epochs, self.val_losses, label="val_loss")
        plt.legend()
    
        plt.show();
        print("loss = ", self.losses[-1], ", val_loss = ", self.val_losses[-1])

# %%
model = Sequential()
model.add(Input(2))
model.add(Dense(20, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(2, activation="softmax"))
model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy')

plot_losses = PlotLosses()
history = model.fit(train_x, train_y, epochs=300, batch_size=128, verbose=0, validation_split=0.2,
                         callbacks=[plot_losses])

plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()
plt.show()
# Out:
# loss =  0.05972226336598396 , val_loss =  0.49568819999694824

# %%
import os, shutil, pathlib

original_dir = pathlib.Path('train')
new_base_dir = pathlib.Path('cats_vs_dogs_small')

def make_subset(subset_name, start_index, end_index):
    for category in ('cat', 'dog'):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f'{category}.{i}.jpg'
                 for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname,
                           dst=dir / fname)
            
make_subset('train', start_index=0, end_index=1000)
make_subset('validation', start_index=1000, end_index=1500)
make_subset('test', start_index=1500, end_index=2000)

# %%
# 강아지 vs 고양이 분류 모델 만들기
from tensorflow import keras
from keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation='relu')(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_5 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_4 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_6 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 18, 18, 256)       295168
#
#  max_pooling2d_7 (MaxPooling  (None, 9, 9, 256)        0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 7, 7, 256)         590080
#
#  flatten_1 (Flatten)         (None, 12544)             0
#
#  dense_16 (Dense)            (None, 1)                 12545
#
# =================================================================
# Total params: 991,041
# Trainable params: 991,041
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 훈련 설정하기
model.compile(loss='binary_crossentropy',
             optimizer='rmsprop',
             metrics=['accuracy'])

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(
    new_base_dir / 'train',
    image_size=(180, 180),
    batch_size=32)

validation_dataset = image_dataset_from_directory(
                        new_base_dir / 'validation',
                        image_size=(180, 180),
                        batch_size=32)

test_dataset = image_dataset_from_directory(
                new_base_dir / 'test',
                image_size=(180, 180),
                batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.

# %% [markdown]
# 찾은 파일들을 2개의 클래스로 나눠두었다는 뜻

# %%
type(train_dataset)

# %%
# Dataset을 사용하여 모델 훈련하기
callbacks = [
    keras.callbacks.ModelCheckpoint(
    filepath='convnet_from_scratch.keras',
    save_best_only=True,
    monitor='val_loss')
]

history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 63/63 [==============================] - 56s 866ms/step - loss: 0.7518 - accuracy: 0.5180 - val_loss: 0.6914 - val_accuracy: 0.5120
# Epoch 2/30
# 63/63 [==============================] - 53s 838ms/step - loss: 0.7167 - accuracy: 0.5405 - val_loss: 0.6858 - val_accuracy: 0.5920
# Epoch 3/30
# 63/63 [==============================] - 53s 845ms/step - loss: 0.6899 - accuracy: 0.5860 - val_loss: 0.6778 - val_accuracy: 0.5430
# Epoch 4/30
# 63/63 [==============================] - 56s 888ms/step - loss: 0.6564 - accuracy: 0.6305 - val_loss: 0.7015 - val_accuracy: 0.5770
# Epoch 5/30
# 63/63 [==============================] - 54s 848ms/step - loss: 0.6255 - accuracy: 0.6680 - val_loss: 0.6713 - val_accuracy: 0.5750
# Epoch 6/30
# 63/63 [==============================] - 53s 834ms/step - loss: 0.6146 - accuracy: 0.6920 - val_loss: 0.5917 - val_accuracy: 0.7000
# Epoch 7/30
# 63/63 [==============================] - 52s 831ms/step - loss: 0.5216 - accuracy: 0.7465 - val_loss: 0.6873 - val_accuracy: 0.6810
# Epoch 8/30
# 63/63 [==============================] - 53s 837ms/step - loss: 0.4845 - accuracy: 0.7710 - val_loss: 0.6597 - val_accuracy: 0.7090
# Epoch 9/30
# 63/63 [==============================] - 57s 900ms/step - loss: 0.4276 - accuracy: 0.7975 - val_loss: 0.6660 - val_accuracy: 0.7070
# Epoch 10/30
# 63/63 [==============================] - 63s 993ms/step - loss: 0.3925 - accuracy: 0.8225 - val_loss: 0.6386 - val_accuracy: 0.7090
# Epoch 11/30
# 63/63 [==============================] - 64s 1s/step - loss: 0.3181 - accuracy: 0.8605 - val_loss: 0.6664 - val_accuracy: 0.7390
# Epoch 12/30
# 63/63 [==============================] - 61s 975ms/step - loss: 0.2618 - accuracy: 0.8905 - val_loss: 0.8239 - val_accuracy: 0.7290
# Epoch 13/30
# 63/63 [==============================] - 63s 994ms/step - loss: 0.2245 - accuracy: 0.9055 - val_loss: 1.0499 - val_accuracy: 0.7020
# Epoch 14/30
# 63/63 [==============================] - 63s 1s/step - loss: 0.1659 - accuracy: 0.9410 - val_loss: 1.0155 - val_accuracy: 0.7290
# Epoch 15/30
# 63/63 [==============================] - 64s 1s/step - loss: 0.1365 - accuracy: 0.9515 - val_loss: 0.9709 - val_accuracy: 0.7400
# Epoch 16/30
# 63/63 [==============================] - 63s 995ms/step - loss: 0.1250 - accuracy: 0.9565 - val_loss: 1.0818 - val_accuracy: 0.7230
# Epoch 17/30
# 63/63 [==============================] - 63s 993ms/step - loss: 0.0903 - accuracy: 0.9680 - val_loss: 1.8201 - val_accuracy: 0.6690
# Epoch 18/30
# 63/63 [==============================] - 67s 1s/step - loss: 0.0826 - accuracy: 0.9705 - val_loss: 1.4889 - val_accuracy: 0.7120
# Epoch 19/30
# 63/63 [==============================] - 66s 1s/step - loss: 0.0708 - accuracy: 0.9795 - val_loss: 1.4387 - val_accuracy: 0.7270
# Epoch 20/30
# 63/63 [==============================] - 63s 1s/step - loss: 0.0634 - accuracy: 0.9800 - val_loss: 1.5045 - val_accuracy: 0.7380
# Epoch 21/30
# 63/63 [==============================] - 54s 851ms/step - loss: 0.0482 - accuracy: 0.9825 - val_loss: 1.7588 - val_accuracy: 0.7380
# Epoch 22/30
# 63/63 [==============================] - 53s 846ms/step - loss: 0.0552 - accuracy: 0.9825 - val_loss: 1.7096 - val_accuracy: 0.7100
# Epoch 23/30
# 63/63 [==============================] - 58s 920ms/step - loss: 0.0633 - accuracy: 0.9755 - val_loss: 1.8651 - val_accuracy: 0.7510
# Epoch 24/30
# 63/63 [==============================] - 69s 1s/step - loss: 0.0406 - accuracy: 0.9855 - val_loss: 1.8891 - val_accuracy: 0.7180
# Epoch 25/30
# 63/63 [==============================] - 71s 1s/step - loss: 0.0598 - accuracy: 0.9815 - val_loss: 2.0229 - val_accuracy: 0.7090
# Epoch 26/30
# 63/63 [==============================] - 62s 976ms/step - loss: 0.0278 - accuracy: 0.9890 - val_loss: 2.3017 - val_accuracy: 0.7380
# Epoch 27/30
# 63/63 [==============================] - 56s 892ms/step - loss: 0.0570 - accuracy: 0.9830 - val_loss: 1.9979 - val_accuracy: 0.7360
# Epoch 28/30
# 63/63 [==============================] - 59s 942ms/step - loss: 0.0465 - accuracy: 0.9890 - val_loss: 2.0689 - val_accuracy: 0.7540
# Epoch 29/30
# 63/63 [==============================] - 63s 1s/step - loss: 0.0343 - accuracy: 0.9910 - val_loss: 2.2877 - val_accuracy: 0.7510
# Epoch 30/30
# 63/63 [==============================] - 62s 992ms/step - loss: 0.0598 - accuracy: 0.9835 - val_loss: 2.3451 - val_accuracy: 0.7420

# %%
# 훈련 과정의 정확도와 손실 그래프 그리기
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
# 테스트 세트에서 모델 평가하기
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 [==============================] - 7s 202ms/step - loss: 0.6150 - accuracy: 0.6690
# Test accuracy: 0.669

# %%
# 컨브넷에 추가할 데이터 증식 단계 정의하기
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %%
# 랜덤하게 증식된 훈련 이미지 출력하기
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %%
import C
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [231], in <cell line: 1>()
# ----> 1 import cv2
#       2 import matplotlib.pyplot as plt
#       3 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#
# ModuleNotFoundError: No module named 'cv2'
