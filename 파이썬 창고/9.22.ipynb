# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/sidsriv/Introduction-to-Data-Science-in-python/master/mpg.csv")

# %%
df = df.iloc[:,1:]
df
# Out:
#       model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0        a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1        a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2        a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3        a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4        a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
# ..      ...    ...   ...  ...         ...  ..  ...  ... ..      ...
# 229  passat    2.0  2008    4    auto(s6)   f   19   28  p  midsize
# 230  passat    2.0  2008    4  manual(m6)   f   21   29  p  midsize
# 231  passat    2.8  1999    6    auto(l5)   f   16   26  p  midsize
# 232  passat    2.8  1999    6  manual(m5)   f   18   26  p  midsize
# 233  passat    3.6  2008    6    auto(s6)   f   17   26  p  midsize
#
# [234 rows x 10 columns]

# %%
df1 = df.rename({'class':'nclass'}, axis = 1)

# %%
df2 = df1.query('nclass in ["compact", "midsize", "suv"]')

# %%
df2['cty'].mean()
# Out:
# 17.013333333333332

# %%
df.drv.unique()
# Out:
# array(['f', '4', 'r'], dtype=object)

# %%
df['cty'].apply(np.sum)
# Out:
# 0      18
# 1      21
# 2      20
# 3      21
# 4      16
#        ..
# 229    19
# 230    21
# 231    16
# 232    18
# 233    17
# Name: cty, Length: 234, dtype: int32

# %% [markdown]
# # 오늘 공부 시작

# %%
exam = pd.read_excel("excel_exam.xlsx")
exam
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 2    3      1    45       86       78
# 3    4      1    30       98       58
# 4    5      2    25       80       65
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 8    9      3    20       98       15
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 11  12      3    45       85       32
# 12  13      4    46       98       65
# 13  14      4    48       87       12
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
exam.rename({'class':'nclass'}, axis = 1, inplace = True)
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.iloc[0,2] = 1
exam.iloc[1,3] = 1
exam.iloc[2,4] = 1
exam[:3]
# Out:
#    id  nclass  math  english  science
# 0   1       1     1       98       50
# 1   2       1    60        1       60
# 2   3       1    45       86        1

# %%
import seaborn as sns
sns.boxplot(data = exam, y = 'math')
# Out:
# <AxesSubplot:ylabel='math'>

# %% [markdown]
# ```
# IQR: Inter Quartile Range 1사분위 ~ 3사분위
# 윗 수염의 끝: 3사분위 + 1.5IQR
# 아랫 수염의 끝: 1사분위 - 1.5IQR
# ```

# %%
exam['math'].quantile(.75)  #3사분위
# Out:
# 75.75

# %%
exam['math'].quantile(.25)   #2사분위
# Out:
# 45.0

# %%
pct75 = exam['math'].quantile(.75)
pct25 = exam['math'].quantile(.25)
IQR = pct75 - pct25
IQR
# Out:
# 30.75

# %%
pct75 + 1.5*IQR
# Out:
# 121.875

# %%
pct25 - 1.5*IQR
# Out:
# -1.125

# %%
mpg = pd.read_csv('https://raw.githubusercontent.com/sidsriv/Introduction-to-Data-Science-in-python/master/mpg.csv')

# %%
mpg = mpg.iloc[:,1:]
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
#cty의 수염의 극단치 값은 각각 얼마입니까?

pct25 = mpg['cty'].quantile(.25)
pct25
# Out:
# 14.0

# %%
pct75 = mpg['cty'].quantile(.75)
pct75
# Out:
# 19.0

# %%
iqr = pct75 - pct25
iqr
# Out:
# 5.0

# %%
pct25 - 1.5*iqr
# Out:
# 6.5

# %%
pct75 + 1.5*iqr
# Out:
# 26.5

# %%
hwy1 = mpg['hwy'] >= 40.5
hwy2 = mpg['hwy'] <= 4.5

mpg[hwy1 | hwy2]
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#           class
# 212     compact
# 221  subcompact
# 222  subcompact

# %%
mpg.query('hwy >= 40.5 | hwy <= 4.5')
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#           class
# 212     compact
# 221  subcompact
# 222  subcompact

# %%
#이상치를 제외한 hwy의 평균은?
mpg[~hwy1 & ~hwy2].mean()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4240\2132076653.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mpg[~hwy1 & ~hwy2].mean()
# displ       3.492208
# year     2003.558442
# cyl         5.913420
# cty        16.658009
# hwy        23.186147
# dtype: float64

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %% [markdown]
# # 산점도

# %%
import seaborn as sns
sns.scatterplot(data = mpg, x = 'displ', y = 'hwy', hue = 'drv')\
.set(xlim =(3,6), ylim=(10,30))
# Out:
# [(3.0, 6.0), (10.0, 30.0)]

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize': [4,3]})   #그림 설정

# %%
sns.scatterplot(data = mpg, x = 'displ', y = 'hwy', hue = 'drv')\
.set(xlim =(3,6), ylim=(10,30))
# Out:
# [(3.0, 6.0), (10.0, 30.0)]

# %%
sns.scatterplot(data = mpg, x = 'displ', y = 'hwy', hue = 'drv')\
.set(xlim =(3,6), ylim=(10,30))
plt.savefig('test.png', dpi = 300)   #저장하기

# %% [markdown]
# 저장하려는 그림이 있다면 한 셀 안에서 같이 입력해야 저장된다.

# %%
#drv 별로 hwy의 평균을 구하기
df_mpg = mpg.groupby('drv')[['hwy']].mean()
df_mpg
# Out:
#            hwy
# drv
# 4    19.174757
# f    28.160377
# r    21.000000

# %%
#인덱스를 칼럼으로 바꾸기
#방법1
df_mpg.reset_index()
# Out:
#   drv        hwy
# 0   4  19.174757
# 1   f  28.160377
# 2   r  21.000000

# %%
#방법2
#groupby로 만들 때, 파라미터로 정하기
df_mpg = mpg.groupby('drv', as_index = False)[['hwy']].mean()

# %%
sns.barplot(data = df_mpg.reset_index(), x = 'drv', y = 'hwy')
# Out:
# <AxesSubplot:xlabel='drv', ylabel='hwy'>

# %%
df_mpg = df_mpg.sort_values(by = 'hwy', ascending = False)
df_mpg
# Out:
#            hwy
# drv
# f    28.160377
# r    21.000000
# 4    19.174757

# %%
sns.barplot(data = df_mpg.reset_index(), x = 'drv', y = 'hwy')
# Out:
# <AxesSubplot:xlabel='drv', ylabel='hwy'>

# %%
import pydataset

# %%
economics = pydataset.data("economics")
economics[:3]
# Out:
#          date    pce     pop  psavert  uempmed  unemploy
# 1  1967-06-30  507.8  198712      9.8      4.5      2944
# 2  1967-07-31  510.9  198911      9.8      4.7      2945
# 3  1967-08-31  516.7  199113      9.0      4.6      2958

# %%
economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478 entries, 1 to 478
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      478 non-null    object
#  1   pce       478 non-null    float64
#  2   pop       478 non-null    int64
#  3   psavert   478 non-null    float64
#  4   uempmed   478 non-null    float64
#  5   unemploy  478 non-null    int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 26.1+ KB

# %%
sns.lineplot(data = economics, x = 'date', y = 'unemploy')
# Out:
# <AxesSubplot:xlabel='date', ylabel='unemploy'>

# %% [markdown]
# 밑에 시커먼 부분은 x축의 date 부분을 전부 표현한 거여서 다 겹쳐서 보이기 때문이다.

# %% [markdown]
# ## 칼럼의 데이터타입 바꾸기 astype()

# %%
economics['unemploy'] = economics['unemploy'].astype('float')
economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478 entries, 1 to 478
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      478 non-null    object
#  1   pce       478 non-null    float64
#  2   pop       478 non-null    int64
#  3   psavert   478 non-null    float64
#  4   uempmed   478 non-null    float64
#  5   unemploy  478 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 26.1+ KB

# %%
economics['date'] = economics['date'].astype('datetime64')
economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478 entries, 1 to 478
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      478 non-null    datetime64[ns]
#  1   pce       478 non-null    float64
#  2   pop       478 non-null    int64
#  3   psavert   478 non-null    float64
#  4   uempmed   478 non-null    float64
#  5   unemploy  478 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 26.1 KB

# %%
sns.lineplot(data = economics, x = 'date', y = 'unemploy')
# Out:
# <AxesSubplot:xlabel='date', ylabel='unemploy'>

# %%
economics['date'] = economics['date'].astype('object')
economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478 entries, 1 to 478
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      478 non-null    object
#  1   pce       478 non-null    float64
#  2   pop       478 non-null    int64
#  3   psavert   478 non-null    float64
#  4   uempmed   478 non-null    float64
#  5   unemploy  478 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 26.1+ KB

# %%
economics['date'] = pd.to_datetime(economics['date'])
economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478 entries, 1 to 478
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      478 non-null    datetime64[ns]
#  1   pce       478 non-null    float64
#  2   pop       478 non-null    int64
#  3   psavert   478 non-null    float64
#  4   uempmed   478 non-null    float64
#  5   unemploy  478 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 26.1 KB

# %% [markdown]
# ```
# 2가지 방법이 있다.
# - pd.to_datetime()
# - astype()
# ```

# %% [markdown]
# - 상자수염 그림

# %%
sns.boxplot(data = mpg, x = 'drv', y = 'hwy')  #변수는 2개여야 한다.
# Out:
# <AxesSubplot:xlabel='drv', ylabel='hwy'>

# %%
sns.boxplot(data = mpg, y = 'hwy')
# Out:
# <AxesSubplot:ylabel='hwy'>

# %% [markdown]
# # 한국복지패널 데이터

# %%
pip install pyreadstat
# Out:
# ...
#      ---------------------------------------- 2.4/2.4 MB 16.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
raw_welfare = pd.read_spss('Koweps_hpwc14_2019_beta3.sav')
raw_welfare
# Out:
#        h14_id  h14_ind  h14_sn  h14_merkey  h_new  h14_cobf   p14_wsc  \
# 0         2.0      1.0     1.0     20101.0    0.0       NaN  0.291589
# 1         3.0      1.0     1.0     30101.0    0.0       NaN  0.419753
# 2         4.0      1.0     1.0     40101.0    0.0       NaN  0.265263
# 3         6.0      1.0     1.0     60101.0    0.0       NaN  0.494906
# 4         6.0      1.0     1.0     60101.0    0.0       NaN  1.017935
# ...       ...      ...     ...         ...    ...       ...       ...
# 14413  9800.0      7.0     1.0  98000701.0    1.0       NaN       NaN
# 14414  9800.0      7.0     1.0  98000701.0    1.0       NaN       NaN
# 14415  9800.0      7.0     1.0  98000701.0    1.0       NaN       NaN
# 14416  9800.0      7.0     1.0  98000701.0    1.0       NaN       NaN
# 14417  9800.0      7.0     1.0  98000701.0    1.0       NaN       NaN
#
#         p14_wsl      p14_wgc      p14_wgl  ...  wc14_64  wc14_65  wc14_5aq4  \
# ...

# %%
welfare = raw_welfare.loc[:, ['h14_g3', 'h14_g4', 'h14_g10', 'h14_g11', 'p1402_8aq1', 'h14_eco9', 'h14_reg7']]
welfare
# Out:
#        h14_g3  h14_g4  h14_g10  h14_g11  p1402_8aq1  h14_eco9  h14_reg7
# 0         2.0  1945.0      2.0      1.0         NaN       NaN       1.0
# 1         1.0  1948.0      2.0      2.0         NaN       NaN       1.0
# 2         1.0  1942.0      3.0      1.0       107.0     762.0       1.0
# 3         1.0  1962.0      1.0      1.0       192.0     855.0       1.0
# 4         2.0  1963.0      1.0      1.0         NaN       NaN       1.0
# ...       ...     ...      ...      ...         ...       ...       ...
# 14413     2.0  1967.0      1.0      1.0         NaN       NaN       5.0
# 14414     2.0  1992.0      5.0      1.0         NaN       NaN       5.0
# 14415     1.0  1995.0      5.0      1.0         NaN     910.0       5.0
# 14416     2.0  1998.0      5.0      1.0       200.0     246.0       5.0
# 14417     1.0  2001.0      0.0      1.0         NaN       NaN       5.0
#
# [14418 rows x 7 columns]

# %%
welfare = welfare.rename(
    columns = {'h14_g3':'sex', 'h14_g4':'birth', 'h14_g10':'marriage_type',
              'h14_g11':'religion', 'p1402_8aq1':'income',
              'h14_eco9':'code_job', 'h14_reg7':'code_region'})

# %%
welfare[:2]
# Out:
#    sex   birth  marriage_type  religion  income  code_job  code_region
# 0  2.0  1945.0            2.0       1.0     NaN       NaN          1.0
# 1  1.0  1948.0            2.0       2.0     NaN       NaN          1.0

# %%
welfare['sex'].value_counts()
# Out:
# female    7912
# male      6506
# Name: sex, dtype: int64

# %%
# sex 별로 income 평균
welfare.groupby('sex')['income'].mean()
# Out:
# sex
# 1.0    349.037571
# 2.0    186.293096
# Name: income, dtype: float64

# %%
#sex에서 1은 male, 2는 female로 바꾸기
welfare['sex'] = np.where(welfare['sex']==1,'male','female')
welfare[:4]
# Out:
#       sex   birth  marriage_type  religion  income  code_job  code_region
# 0  female  1945.0            2.0       1.0     NaN       NaN          1.0
# 1    male  1948.0            2.0       2.0     NaN       NaN          1.0
# 2    male  1942.0            3.0       1.0   107.0     762.0          1.0
# 3    male  1962.0            1.0       1.0   192.0     855.0          1.0

# %%
welfare.groupby('sex')[['income']].mean()
# Out:
#             income
# sex
# female  186.293096
# male    349.037571

# %%
df = welfare.groupby('sex', as_index=False)[['income']].mean()
df
# Out:
#       sex      income
# 0  female  186.293096
# 1    male  349.037571

# %%
sns.barplot(data = df, x = 'sex', y = 'income')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='income'>

# %% [markdown]
# - 나이별로 월급 평균 구하기

# %%
welfare[:2]
# Out:
#       sex   birth  marriage_type  religion  income  code_job  code_region
# 0  female  1945.0            2.0       1.0     NaN       NaN          1.0
# 1    male  1948.0            2.0       2.0     NaN       NaN          1.0

# %%
min(welfare.birth)
max(welfare.birth)
# Out:
# 2018.0

# %% [markdown]
# ```
# 2018년이 1살
# 2017년이 2살
# 2016년이 3살
# ...
# age 열을 만들어라.
# ```

# %%
welfare['age'] = 2019 - welfare['birth']
welfare[:2]
# Out:
#       sex   birth  marriage_type  religion  income  code_job  code_region  \
# 0  female  1945.0            2.0       1.0     NaN       NaN          1.0
# 1    male  1948.0            2.0       2.0     NaN       NaN          1.0
#
#     age
# 0  74.0
# 1  71.0

# %%
# age 열을 int로 바꾸기
welfare['age'] = welfare['age'].astype('int')
welfare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14418 entries, 0 to 14417
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sex            14418 non-null  object
#  1   birth          14418 non-null  float64
#  2   marriage_type  14418 non-null  float64
#  3   religion       14418 non-null  float64
#  4   income         4534 non-null   float64
#  5   code_job       6878 non-null   float64
#  6   code_region    14418 non-null  float64
#  7   age            14418 non-null  int32
# dtypes: float64(6), int32(1), object(1)
# memory usage: 844.9+ KB

# %%
#나이별로 소득의 평균을 구해주세요.
df = welfare.groupby('age').agg('mean')[['income']]

# %%
df = df.reset_index()
df
# Out:
#      age      income
# 0      1         NaN
# 1      2         NaN
# 2      3         NaN
# 3      4         NaN
# 4      5         NaN
# 5      6         NaN
# 6      7         NaN
# 7      8         NaN
# 8      9         NaN
# 9     10         NaN
# 10    11         NaN
# 11    12         NaN
# 12    13         NaN
# 13    14         NaN
# 14    15         NaN
# 15    16         NaN
# 16    17         NaN
# 17    18  162.000000
# 18    19  121.333333
# 19    20  136.400000
# 20    21  123.666667
# 21    22  179.676471
# 22    23  143.742857
# 23    24  190.433333
# 24    25  190.430233
# 25    26  223.826667
# 26    27  220.616438
# 27    28  230.955556
# 28    29  247.696203
# 29    30  266.134831
# 30    31  276.297872
# 31    32  268.865385
# 32    33  281.176471
# 33    34  305.603175
# 34    35  302.467742
# 35    36  306.010870
# 36    37  334.539216
# 37    38  317.055556
# 38    39  341.694444
# 39    40  351.525424
# 40    41  324.137615
# 41    42  344.811881
# ...

# %%
#df로 lineplot을 그려보기
sns.lineplot(df, x = 'age', y= 'income')
# Out:
# <AxesSubplot:xlabel='age', ylabel='income'>

# %% [markdown]
# ```
# 새 칼럼 : age_gen
# 30이하 : young
# 60이하 : middle
# 나머지 : old
# ```

# %%
welfare['age_gen'] = np.where(welfare['age'] <= 30, 
                              'young', np.where(welfare['age'] <= 60, 
                                                'middle', 'old')) 
welfare
# Out:
#           sex   birth  marriage_type  religion  income  code_job  code_region  \
# 0      female  1945.0            2.0       1.0     NaN       NaN          1.0
# 1        male  1948.0            2.0       2.0     NaN       NaN          1.0
# 2        male  1942.0            3.0       1.0   107.0     762.0          1.0
# 3        male  1962.0            1.0       1.0   192.0     855.0          1.0
# 4      female  1963.0            1.0       1.0     NaN       NaN          1.0
# ...       ...     ...            ...       ...     ...       ...          ...
# 14413  female  1967.0            1.0       1.0     NaN       NaN          5.0
# 14414  female  1992.0            5.0       1.0     NaN       NaN          5.0
# 14415    male  1995.0            5.0       1.0     NaN     910.0          5.0
# 14416  female  1998.0            5.0       1.0   200.0     246.0          5.0
# 14417    male  2001.0            0.0       1.0     NaN       NaN          5.0
#
#        age age_gen
# ...

# %%
#'category'로 데이터타입을 바꿔 주세요.

welfare['age_gen'] = welfare['age_gen'].astype('category')
welfare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14418 entries, 0 to 14417
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sex            14418 non-null  object
#  1   birth          14418 non-null  float64
#  2   marriage_type  14418 non-null  float64
#  3   religion       14418 non-null  float64
#  4   income         4534 non-null   float64
#  5   code_job       6878 non-null   float64
#  6   code_region    14418 non-null  float64
#  7   age            14418 non-null  int32
#  8   age_gen        14418 non-null  category
# dtypes: category(1), float64(6), int32(1), object(1)
# memory usage: 859.1+ KB

# %%
#세대별 소득평균, income, age_gen, gender

df_gen = welfare.groupby(['age_gen','sex']).agg('mean')[['income']]
df_gen
# Out:
#                     income
# age_gen sex
# middle  female  226.226646
#         male    413.188540
# old     female   81.132597
#         male    166.415789
# young   female  198.790404
#         male    227.636364

# %%
df_gen = df_gen.reset_index()

# %%
#세대별 성별 소득평균

sns.barplot(data = df_gen, x = 'age_gen', y = 'income', hue = 'sex', 
            order = ['young','middle','old'], palette = 'Set1')
# Out:
# <AxesSubplot:xlabel='age_gen', ylabel='income'>

# %% [markdown]
# # 텍스트 마이닝

# %%
pip install jpype1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install konlpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
moon = open('speech_moon.txt', encoding = 'utf-8').read()
moon
# Out:
# '정권교체 하겠습니다!\n  정치교체 하겠습니다!\n  시대교체 하겠습니다!\n  \n  ‘불비불명(不飛不鳴)’이라는 고사가 있습니다. 남쪽 언덕 나뭇가지에 앉아, 3년 동안 날지도 울지도 않는 새. 그러나 그 새는 한번 날면 하늘 끝까지 날고, 한번 울면 천지를 뒤흔듭니다.\n\n그 동안 정치와 거리를 둬 왔습니다. 그러나 암울한 시대가 저를 정치로 불러냈습니다. 더 이상 남쪽 나뭇가지에 머무를 수 없었습니다. 이제 저는 국민과 함께 높이 날고 크게 울겠습니다. 오늘 저는 제18대 대통령선거 출마를 국민 앞에 엄숙히 선언합니다.\n\n\n‘우리나라 대통령’이 되겠습니다.\n\n\n존경하는 국민 여러분!\n  \n  저는 대통령이 되겠습니다. 우리나라 대통령이 되겠습니다. 소수 특권층의 나라가 아니라 보통사람들이 주인인 ‘우리나라’, 네 편 내 편 편가르지 않고 함께 가는 우리나라, ‘우리’라는 말이 조금도 부끄럽지 않은, 진정한 ‘우리나라’의 대통령이 되겠습니다.\n\n지금까지 우리 보통사람들은 날지도 울지도 못하는 새였습니다. 나라의 주인으로 행세하지 못했고, 주인으로 대접받지 못했습니다. 나서서 말도 하지 못했습니다. 이제 몸을 일으켜 날아야 합니다. 당당하게 말하고 정치에 참여해야 합니다.\n\n제가 추구하는 ‘우리나라’는 정치인에게 맡겨놓는 나라가 아니라 시민이 직접 정치와 정책과정에 참여하는 나라입니다. 저는 시민과 동행하는 정치를 하고 싶습니다. 제가 추구하는 ‘우리나라’는 특권과 불평등의 나라가 아니라, 보통사람들이 함께 기회를 가지는 공평하고 정의로운 나라입니다.\n\n이제 권력과 돈을 가진 집단이 나라를 그들 마음대로 움직이던 시대는 끝났습니다. 힘없는 사람들에게 끝없이 희생을 강요하던 낡은 경제, 낡은 정치, 낡은 권력도 모두 끝났습니다. 오늘 저 문재인은 우리나라를 우리 모두의 나라로 선언합니다.\n\n국민이 모두 아픕니다.\n\n제가 높이 날고 크게 울겠다고 결심한 이유는 보통사람들의 삶이 너무 고달프고, 우리가 처한 현실이 너무도 
# ...

# %%
#불필요한 문자 제거
import re
moon = re.sub('[^가-힣]', ' ', moon)
moon
# Out:
# '정권교체 하겠습니다    정치교체 하겠습니다    시대교체 하겠습니다        불비불명       이라는 고사가 있습니다  남쪽 언덕 나뭇가지에 앉아   년 동안 날지도 울지도 않는 새  그러나 그 새는 한번 날면 하늘 끝까지 날고  한번 울면 천지를 뒤흔듭니다   그 동안 정치와 거리를 둬 왔습니다  그러나 암울한 시대가 저를 정치로 불러냈습니다  더 이상 남쪽 나뭇가지에 머무를 수 없었습니다  이제 저는 국민과 함께 높이 날고 크게 울겠습니다  오늘 저는 제  대 대통령선거 출마를 국민 앞에 엄숙히 선언합니다     우리나라 대통령 이 되겠습니다    존경하는 국민 여러분       저는 대통령이 되겠습니다  우리나라 대통령이 되겠습니다  소수 특권층의 나라가 아니라 보통사람들이 주인인  우리나라   네 편 내 편 편가르지 않고 함께 가는 우리나라   우리 라는 말이 조금도 부끄럽지 않은  진정한  우리나라 의 대통령이 되겠습니다   지금까지 우리 보통사람들은 날지도 울지도 못하는 새였습니다  나라의 주인으로 행세하지 못했고  주인으로 대접받지 못했습니다  나서서 말도 하지 못했습니다  이제 몸을 일으켜 날아야 합니다  당당하게 말하고 정치에 참여해야 합니다   제가 추구하는  우리나라 는 정치인에게 맡겨놓는 나라가 아니라 시민이 직접 정치와 정책과정에 참여하는 나라입니다  저는 시민과 동행하는 정치를 하고 싶습니다  제가 추구하는  우리나라 는 특권과 불평등의 나라가 아니라  보통사람들이 함께 기회를 가지는 공평하고 정의로운 나라입니다   이제 권력과 돈을 가진 집단이 나라를 그들 마음대로 움직이던 시대는 끝났습니다  힘없는 사람들에게 끝없이 희생을 강요하던 낡은 경제  낡은 정치  낡은 권력도 모두 끝났습니다  오늘 저 문재인은 우리나라를 우리 모두의 나라로 선언합니다   국민이 모두 아픕니다   제가 높이 날고 크게 울겠다고 결심한 이유는 보통사람들의 삶이 너무 고달프고  우리가 처한 현실이 너무도 엄중하기 때문입니다  근본적인 혁신  거대한
# ...

# %%
#명사 추출
import konlpy
hannanum = konlpy.tag.Hannanum()

hannanum.nouns("대한민국의 영토는 한반도와 그 부속도서로 한다")
# Out:
# ['대한민국', '영토', '한반도', '부속도서']

# %%
nouns = hannanum.nouns(moon)
nouns
# Out:
# ['정권교체',
#  '정치교체',
#  '시대교체',
#  '불비불명',
#  '고사',
#  '남쪽',
#  '언덕',
#  '나뭇가지',
#  '년',
#  '동안',
#  '새',
#  '한번',
#  '하늘',
#  '끝',
#  '한번',
#  '천지',
#  '동안',
#  '정치',
#  '거리',
#  '암울한',
#  '시대',
#  '저',
#  '정치',
#  '이상',
#  '남쪽',
#  '나뭇가지',
#  '수',
#  '저',
#  '국민',
#  '오늘',
#  '저',
#  '저',
#  '대',
#  '대통령선거',
#  '출마',
#  '국민',
#  '앞',
#  '선언',
#  '우리나라',
#  '대통령',
#  '존경',
#  '국민',
#  '여러분',
#  '저',
#  '대통령',
#  '우리나라',
#  '대통령',
#  '소수',
#  '특권층',
#  '나라',
#  '보통사람들',
#  '주인',
#  '우리나라',
#  '네',
#  '편',
#  '내',
#  '편',
#  '편가르지',
#  '우리나라',
#  '우리',
#  '라',
#  '말',
#  '진정한',
#  '우리나라',
#  '의',
#  '대통령',
#  '지금',
#  '우리',
#  '보통사람들',
#  '새',
#  '나라',
#  '주인',
#  '행세',
#  '주인',
#  '대접',
#  '말',
#  '몸',
#  '당당',
#  '말',
#  '정치',
#  '참여',
#  '저',
#  '추구',
#  '우리나라',
#  '정치인',
#  '나라',
#  '시민',
#  '정치',
#  '정책과정',
#  '참여',
#  '나라',
#  '저',
#  '시민',
#  '동행',
#  '정치',
#  '저',
#  '추구',
#  '우리나라',
#  '특권',
#  '불평등',
#  '나라',
#  '보통사람들',
#  '기회',
#  '공평',
#  '정의로운',
#  '나라',
#  '권력',
#  '돈',
# ...

# %%
#데이터 프레임으로 변환
import pandas as pd
df_word = pd.DataFrame({'word':nouns})
df_word
# Out:
#       word
# 0     정권교체
# 1     정치교체
# 2     시대교체
# 3     불비불명
# 4       고사
# ...    ...
# 1408    모두
# 1409    주인
# 1410   진정한
# 1411  우리나라
# 1412   대통령
#
# [1413 rows x 1 columns]

# %%
#단어 빈도표
df_word['count'] = df_word['word'].str.len()
df_word
# Out:
#       word  count
# 0     정권교체      4
# 1     정치교체      4
# 2     시대교체      4
# 3     불비불명      4
# 4       고사      2
# ...    ...    ...
# 1408    모두      2
# 1409    주인      2
# 1410   진정한      3
# 1411  우리나라      4
# 1412   대통령      3
#
# [1413 rows x 2 columns]

# %%
#두 글자 이상 단어만 남기기
df_word = df_word.query('count >= 2')
df_word.sort_values('count')
# Out:
#           word  count
# 712         국민      2
# 1164        가사      2
# 1163        숙제      2
# 1162        평등      2
# 644         확대      2
# ...        ...    ...
# 707     평생학습체제      6
# 1268    군사대결지대      6
# 173     성적스트레스      6
# 978   고용영향평가제도      8
# 1055  국가일자리위원회      8
#
# [1187 rows x 2 columns]

# %%
#단어 빈도
df_word = df_word.groupby('word', as_index = False).agg(n=('word', 'count')).sort_values('n', ascending=False)
df_word
# Out:
#      word   n
# 153    나라  19
# 462   일자리  19
# 116    국민  18
# 422    우리  17
# 198   대통령  12
# ..    ...  ..
# 278  북핵문제   1
# 279    분단   1
# 281    분야   1
# 283    분쟁   1
# 355    수천   1
#
# [710 rows x 2 columns]

# %%
top20 = df_word.head(20)
top20
# Out:
#      word   n
# 153    나라  19
# 462   일자리  19
# 116    국민  18
# 422    우리  17
# 198   대통령  12
# 202  대한민국  11
# 693    확대  11
# 525    정치  10
# 423  우리나라  10
# 304    사회   9
# 298    사람   9
# 332    성장   9
# 646    평화   8
# 266  복지국가   8
# 265    복지   8
# 308    산업   7
# 517    정부   7
# 609    추진   7
# 103    교육   6
# 339    세상   6

# %%
import seaborn as sns
sns.barplot(data = top20, x = 'word', y = 'n')
plt.xticks(rotation=10)
plt.show()

# %%
sns.barplot(data = top20, x = 'n', y = 'word')
# Out:
# <AxesSubplot:xlabel='n', ylabel='word'>

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
font = 'DoHyeon-Regular.ttf'

# %%
dic_word = df_word.set_index('word').to_dict()['n']
dic_word
# Out:
# {'나라': 19,
#  '일자리': 19,
#  '국민': 18,
#  '우리': 17,
#  '대통령': 12,
#  '대한민국': 11,
#  '확대': 11,
#  '정치': 10,
#  '우리나라': 10,
#  '사회': 9,
#  '사람': 9,
#  '성장': 9,
#  '평화': 8,
#  '복지국가': 8,
#  '복지': 8,
#  '산업': 7,
#  '정부': 7,
#  '추진': 7,
#  '교육': 6,
#  '세상': 6,
#  '경쟁': 6,
#  '보통사람들': 5,
#  '공평': 5,
#  '경제': 5,
#  '대통령의': 5,
#  '상생': 5,
#  '정규직': 5,
#  '정의': 4,
#  '결과': 4,
#  '사회적': 4,
#  '투자': 4,
#  '주인': 4,
#  '전환': 4,
#  '때문': 4,
#  '모델': 4,
#  '요구': 4,
#  '희망': 4,
#  '창출': 4,
#  '역사': 4,
#  '기회': 4,
#  '여성': 4,
#  '담쟁': 4,
#  '강화': 4,
#  '아래': 4,
#  '고통': 4,
#  '약자': 4,
#  '아이들': 4,
#  '중소기업': 4,
#  '공정': 3,
#  '문재인': 3,
#  '특권': 3,
#  '국가': 3,
#  '사람들': 3,
#  '노인': 3,
#  '변화': 3,
#  '비중': 3,
#  '교육혁신': 3,
#  '관계': 3,
#  '질서': 3,
#  '군대': 3,
#  '지원': 3,
#  '과도한': 3,
#  '권력': 3,
#  '부담': 3,
#  '그것': 3,
#  '지방': 3,
#  '국민들': 3,
#  '채택': 3,
#  '소수': 3,
#  '세계': 3,
#  '신산업': 3,
#  '시민': 3,
#  '개선': 3,
#  '혁신': 3,
#  '혁명': 3,
#  '양극화': 3,
#  '원칙': 3,
#  '활용': 3,
#  '행복': 3,
#  '원전': 3,
# ...

# %%
from wordcloud import WordCloud
wc = WordCloud(random_state = 1234,
               font_path = font,
               width = 400,
               height = 400,
               background_color = 'white')

# %%
img_wordcloud = wc.generate_from_frequencies(dic_word)

plt.figure(figsize = (10,10))
plt.axis('off')
plt.imshow(img_wordcloud)

# %%
import PIL
icon = PIL.Image.open('cloud.png')
icon
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=825x467 at 0x1C22AA1D940>

# %%
import numpy as np
img = PIL.Image.new('RGB', icon.size, (255,255,255))
img.paste(icon,icon)
img = np.array(img)

# %%
wc = WordCloud(random_state = 1234,
              font_path = font,
              width = 400,
              height = 400,
              background_color = 'white',
              mask=img)

# %%
img_wordcloud=wc.generate_from_frequencies(dic_word)

plt.figure(figsize = (10,10))
plt.axis('off')
plt.imshow(img_wordcloud)
