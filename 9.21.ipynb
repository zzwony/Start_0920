# %% [markdown]
# # 오전 연습문제

# %%
df = pd.DataFrame({'v1' : [1,2,1],'v2':[5,3,2]})
df
# Out:
#    v1  v2
# 0   1   5
# 1   2   3
# 2   1   2

# %%
df.rename({'v1':'V1', 'v2':'V2'}, axis = 1)
# Out:
#    V1  V2
# 0   1   5
# 1   2   3
# 2   1   2

# %%
import datetime
import time

end = datetime.datetime(2023,2,24)
now = datetime.datetime.now()

end - now
# Out:
# datetime.timedelta(days=155, seconds=52836, microseconds=149415)

# %%
(end-now).days
# Out:
# 155

# %%
pd.DataFrame({'a':[1,2,3],'b':[4,5,6]})
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
a = pd.DataFrame([[1,4],[2,5],[3,6]], columns = ['a','b'])
a
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
pd.DataFrame([[1,4],[2,5],[3,6]], index = ['a','b','c'], columns = ['a','b'])
# Out:
#    a  b
# a  1  4
# b  2  5
# c  3  6

# %%
a = a.rename({'a' : 'A', 'b' : 'B'}, axis = 1) 
a
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
a['합'] = a['A'] + a['B']
a
# Out:
#    A  B  합
# 0  1  4  5
# 1  2  5  7
# 2  3  6  9

# %%
df = pd.read_excel("excel_exam.xlsx")
df
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 2    3      1    45       86       78
# 3    4      1    30       98       58
# 4    5      2    25       80       65
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 8    9      3    20       98       15
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 11  12      3    45       85       32
# 12  13      4    46       98       65
# 13  14      4    48       87       12
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
df['평균'] = (df['math']+df['english']+df['science'])/3
df[:2]
# Out:
#    id  class  math  english  science         평균
# 0   1      1    50       98       50  66.000000
# 1   2      1    60       97       60  72.333333

# %%
df['평균'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['합격여부'] = np.where(df['평균'] > 60, '합격', '불합격')
df[:5]
# Out:
#    id  class  math  english  science         평균 합격여부
# 0   1      1    50       98       50  66.000000   합격
# 1   2      1    60       97       60  72.333333   합격
# 2   3      1    45       86       78  69.666667   합격
# 3   4      1    30       98       58  62.000000   합격
# 4   5      2    25       80       65  56.666667  불합격

# %%
pip install seaborn
# Out:
# ...
#      -------------------------------------- 285.1/285.1 kB 5.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
#seaborn 한글깨짐 현상이 있을때 맑은 고딕으로 밀어 넣겠다는 뜻

# %%
import seaborn as sns
sns.countplot(data = df, x = '합격여부')
# Out:
# <AxesSubplot:xlabel='합격여부', ylabel='count'>

# %% [markdown]
# # 오늘 공부 시작
# - p132

# %%
exam = pd.read_excel("excel_exam.xlsx")
exam
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 2    3      1    45       86       78
# 3    4      1    30       98       58
# 4    5      2    25       80       65
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 8    9      3    20       98       15
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 11  12      3    45       85       32
# 12  13      4    46       98       65
# 13  14      4    48       87       12
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
# class == 1을 찾아라
exam['class'] == 1   # 트루 폴스
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: class, dtype: bool

# %%
exam[exam['class'] == 1]   #안에 넣어주면 이렇게 검색이 된다.
# Out:
#    id  class  math  english  science
# 0   1      1    50       98       50
# 1   2      1    60       97       60
# 2   3      1    45       86       78
# 3   4      1    30       98       58

# %%
# math >= 50 을 찾아라.
exam[exam['math'] >= 50]
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
# 1반이면서 수학이 50점 이상을 찾아라.
exam[(exam['class'] == 1) & (exam['math'] >= 50)]

#exam[exam['class'] == 1) & (exam['math'] >= 50]
#주석처럼 하면 오류 발생.
# Out:
#    id  class  math  english  science
# 0   1      1    50       98       50
# 1   2      1    60       97       60

# %%
#위에와 같은 방법. 이것처럼 변수를 따로 두는것이 안전함.

cond1 = exam['class'] == 1
cond2 = exam['math'] >= 50

exam[cond1 & cond2]
# Out:
#    id  class  math  english  science
# 0   1      1    50       98       50
# 1   2      1    60       97       60

# %%
exam.query('math >= 50')   #따옴표는 문자열을 뜻한다.
                           # 수학이 50점 이상이라는 문장을 의미해야한다.
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
exam.query('math >= 50 & english > 90')  # &도 괄호 안에 넣지 않으면 오류 발생.
                                         # and라고 써줘도 가능
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 9   10      3    50       98       45
# 15  16      4    58       98       65

# %%
#1반이면서 수학이 50점 이상.
exam.query('class = 1 and math >= 50')
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:3398 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [104] in <cell line: 2>
#     exam.query('class = 1 and math >= 50')
#
#   File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4111 in query
#     res = self.eval(expr, **kwargs)
#
#   File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4240 in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\eval.py:351 in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expr.py:811 in __init__
#     self.terms = self.parse()
#
# ...

# %% [markdown]
# ```
# 오류 이유:
# class가 예약어이기 때문이다.
# 그래서 칼럼에 class가 들어가면 안된다.
# ```

# %%
exam.rename({'class':'nclass'}, axis = 1, inplace = True)

# %%
exam.query('nclass ==1 and math >= 50')  # 오류가 해결됨.
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
exam.query('nclass in [1,3,5]')
# nclass == 1 보통은 이렇게 쓰는데 여러개를 찾아야하므로 in을 사용하였다.
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# ```
# [1,2,3,4,5] in [1,3,5]
# 왼쪽 묶음에서 1,3,5가 있는지 잡아낸것이다.
# ```

# %%
df = pd.DataFrame({'sex':['F','M','F','M'],
                  'country':["Korea","China","Japan","USA"]})
df
# Out:
#   sex country
# 0   F   Korea
# 1   M   China
# 2   F   Japan
# 3   M     USA

# %%
df.query('sex == "F" and country == "Korea"')
# Out:
#   sex country
# 0   F   Korea

# %%
exam.iloc[:, 2:]
# Out:
#     math  english  science
# 0     50       98       50
# 1     60       97       60
# 2     45       86       78
# 3     30       98       58
# 4     25       80       65
# 5     50       89       98
# 6     80       90       45
# 7     90       78       25
# 8     20       98       15
# 9     50       98       45
# 10    65       65       65
# 11    45       85       32
# 12    46       98       65
# 13    48       87       12
# 14    75       56       78
# 15    58       98       65
# 16    65       68       98
# 17    80       78       90
# 18    89       68       87
# 19    78       83       58

# %%
exam.loc[:, ['math','english','science']]
# Out:
#     math  english  science
# 0     50       98       50
# 1     60       97       60
# 2     45       86       78
# 3     30       98       58
# 4     25       80       65
# 5     50       89       98
# 6     80       90       45
# 7     90       78       25
# 8     20       98       15
# 9     50       98       45
# 10    65       65       65
# 11    45       85       32
# 12    46       98       65
# 13    48       87       12
# 14    75       56       78
# 15    58       98       65
# 16    65       68       98
# 17    80       78       90
# 18    89       68       87
# 19    78       83       58

# %%
exam[:2] #이런 방법도 있고 drop이란 방법도 있다.
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
exam.drop(['id','nclass'], axis = 1)
# Out:
#     math  english  science
# 0     50       98       50
# 1     60       97       60
# 2     45       86       78
# 3     30       98       58
# 4     25       80       65
# 5     50       89       98
# 6     80       90       45
# 7     90       78       25
# 8     20       98       15
# 9     50       98       45
# 10    65       65       65
# 11    45       85       32
# 12    46       98       65
# 13    48       87       12
# 14    75       56       78
# 15    58       98       65
# 16    65       68       98
# 17    80       78       90
# 18    89       68       87
# 19    78       83       58

# %% [markdown]
# ## 정렬 sort
# - sort_values()  값으로 정렬
# - sort_index()   인덱스로 정렬

# %%
exam.sort_values(by='math')
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 4    5       2    25       80       65
# 3    4       1    30       98       58
# 2    3       1    45       86       78
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 0    1       1    50       98       50
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 15  16       4    58       98       65
# 1    2       1    60       97       60
# 10  11       3    65       65       65
# 16  17       5    65       68       98
# 14  15       4    75       56       78
# 19  20       5    78       83       58
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 7    8       2    90       78       25

# %%
#수학 열 기준
exam.sort_values(by='math', ascending=False)
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 6    7       2    80       90       45
# 19  20       5    78       83       58
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 10  11       3    65       65       65
# 1    2       1    60       97       60
# 15  16       4    58       98       65
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 0    1       1    50       98       50
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 11  12       3    45       85       32
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 8    9       3    20       98       15

# %%
df = exam.sort_values(by=['math','english'], ascending=False)
df
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 19  20       5    78       83       58
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 10  11       3    65       65       65
# 1    2       1    60       97       60
# 15  16       4    58       98       65
# 0    1       1    50       98       50
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 2    3       1    45       86       78
# 11  12       3    45       85       32
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 8    9       3    20       98       15

# %%
df.sort_index()  #인덱스 기준으로 가지런히 줄세운다.
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# ## 칼럼 추가하기

# %%
# total이라는 math, english, science
exam['total'] = exam['math']+exam['english']+exam['science']
exam
# Out:
#     id  nclass  math  english  science  total
# 0    1       1    50       98       50    198
# 1    2       1    60       97       60    217
# 2    3       1    45       86       78    209
# 3    4       1    30       98       58    186
# 4    5       2    25       80       65    170
# 5    6       2    50       89       98    237
# 6    7       2    80       90       45    215
# 7    8       2    90       78       25    193
# 8    9       3    20       98       15    133
# 9   10       3    50       98       45    193
# 10  11       3    65       65       65    195
# 11  12       3    45       85       32    162
# 12  13       4    46       98       65    209
# 13  14       4    48       87       12    147
# 14  15       4    75       56       78    209
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 17  18       5    80       78       90    248
# 18  19       5    89       68       87    244
# ...

# %%
exam.assign(total1 = exam['math']+exam['english']+exam['science'])
# Out:
#     id  nclass  math  english  science  total  total1
# 0    1       1    50       98       50    198     198
# 1    2       1    60       97       60    217     217
# 2    3       1    45       86       78    209     209
# 3    4       1    30       98       58    186     186
# 4    5       2    25       80       65    170     170
# 5    6       2    50       89       98    237     237
# 6    7       2    80       90       45    215     215
# 7    8       2    90       78       25    193     193
# 8    9       3    20       98       15    133     133
# 9   10       3    50       98       45    193     193
# 10  11       3    65       65       65    195     195
# 11  12       3    45       85       32    162     162
# 12  13       4    46       98       65    209     209
# 13  14       4    48       87       12    147     147
# 14  15       4    75       56       78    209     209
# 15  16       4    58       98       65    221     221
# ...

# %% [markdown]
# ## 집단별로 요약하기(그룹짓기)

# %%
exam.groupby('nclass')

# %%
list(exam.groupby('nclass'))
# Out:
# [(1,
#      id  nclass  math  english  science  total
#   0   1       1    50       98       50    198
#   1   2       1    60       97       60    217
#   2   3       1    45       86       78    209
#   3   4       1    30       98       58    186),
#  (2,
#      id  nclass  math  english  science  total
#   4   5       2    25       80       65    170
#   5   6       2    50       89       98    237
#   6   7       2    80       90       45    215
#   7   8       2    90       78       25    193),
#  (3,
#       id  nclass  math  english  science  total
#   8    9       3    20       98       15    133
#   9   10       3    50       98       45    193
#   10  11       3    65       65       65    195
#   11  12       3    45       85       32    162),
#  (4,
#       id  nclass  math  english  science  total
#   12  13       4    46       98       65    209
#   13  14       4    48       87       12    147
#   14  15       4    75       56       78    209
# ...

# %%
exam.groupby('nclass').min()
# Out:
#         id  math  english  science  total
# nclass
# 1        1    30       86       50    186
# 2        5    25       78       25    170
# 3        9    20       65       15    133
# 4       13    46       56       12    147
# 5       17    65       68       58    219

# %%
exam.groupby('nclass').min()['math']
# Out:
# nclass
# 1    30
# 2    25
# 3    20
# 4    46
# 5    65
# Name: math, dtype: int64

# %%
exam.groupby('nclass').min()[['math']]
# Out:
#         math
# nclass
# 1         30
# 2         25
# 3         20
# 4         46
# 5         65

# %%
exam.groupby('nclass').min()[['math', 'science']]
# Out:
#         math  science
# nclass
# 1         30       50
# 2         25       25
# 3         20       15
# 4         46       12
# 5         65       58

# %%
exam[['nclass', 'math', 'science']].groupby('nclass').min()
# Out:
#         math  science
# nclass
# 1         30       50
# 2         25       25
# 3         20       15
# 4         46       12
# 5         65       58

# %%
list(exam[['nclass', 'math', 'science']].groupby('nclass'))
# Out:
# [(1,
#      nclass  math  science
#   0       1    50       50
#   1       1    60       60
#   2       1    45       78
#   3       1    30       58),
#  (2,
#      nclass  math  science
#   4       2    25       65
#   5       2    50       98
#   6       2    80       45
#   7       2    90       25),
#  (3,
#       nclass  math  science
#   8        3    20       15
#   9        3    50       45
#   10       3    65       65
#   11       3    45       32),
#  (4,
#       nclass  math  science
#   12       4    46       65
#   13       4    48       12
#   14       4    75       78
#   15       4    58       65),
#  (5,
#       nclass  math  science
#   16       5    65       98
#   17       5    80       90
#   18       5    89       87
#   19       5    78       58)]

# %%
pip install pydataset
# Out:
# ...
#   Using cached pydataset-0.2.0.tar.gz (15.9 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
# Using legacy 'setup.py install' for pydataset, since package 'wheel' is not installed.
# ...
#   Running setup.py install for pydataset: started
#   Running setup.py install for pydataset: finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pydataset
mpg = pydataset.data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %% [markdown]
# drv 와 class로 그룹을 짓고, 각 그룹별 cty의 min()을 구하여라

# %%
mpg.groupby(['drv','class']).min()[['cty','hwy']]
# Out:
#                 cty  hwy
# drv class
# 4   compact      15   25
#     midsize      15   23
#     pickup        9   12
#     subcompact   19   26
#     suv           9   12
# f   compact      16   23
#     midsize      16   25
#     minivan      11   17
#     subcompact   16   24
# r   2seater      15   23
#     subcompact   14   20
#     suv          11   15

# %%
mpg.groupby(['drv','class']).agg(min)[['cty']]  # 위에랑 결과가 같다.
# Out:
#                 cty
# drv class
# 4   compact      15
#     midsize      15
#     pickup        9
#     subcompact   19
#     suv           9
# f   compact      16
#     midsize      16
#     minivan      11
#     subcompact   16
# r   2seater      15
#     subcompact   14
#     suv          11

# %%
mpg.groupby(['drv']).min()[['cty']]  
# 대괄호가 2개인 이유는 cty는 1개 이지만 두번 처리하기 위해서이다.
# Out:
#      cty
# drv
# 4      9
# f     11
# r     11

# %%
mpg[['drv','cty']].groupby(['drv']).min()
# Out:
#      cty
# drv
# 4      9
# f     11
# r     11

# %%
mpg.groupby(['drv','class']).apply(min)
# Out:
#                manufacturer               model  displ  year  cyl     trans  \
# drv class
# 4   compact            audi          a4 quattro    1.8  1999    4  auto(l5)
#     midsize            audi          a6 quattro    2.8  1999    6  auto(l5)
#     pickup            dodge   dakota pickup 4wd    2.7  1999    4  auto(l4)
#     subcompact       subaru         impreza awd    2.2  1999    4  auto(l4)
#     suv           chevrolet         4runner 4wd    2.5  1999    4  auto(l4)
# f   compact            audi                  a4    1.8  1999    4  auto(av)
#     midsize       chevrolet              altima    1.8  1999    4  auto(av)
#     minivan           dodge         caravan 2wd    2.4  1999    4  auto(l3)
#     subcompact        honda               civic    1.6  1999    4  auto(l4)
# r   2seater       chevrolet            corvette    5.7  1999    8  auto(l4)
#     subcompact         ford             mustang    3.8  1999    6  auto(l4)
# ...

# %%
mpg.groupby(['drv','class']).agg([min, max])[['cty']]

# %%
mpg.groupby(['drv','class']).agg({'cty':min,'hwy':max})
# Out:
#                 cty  hwy
# drv class
# 4   compact      15   28
#     midsize      15   25
#     pickup        9   22
#     subcompact   19   26
#     suv           9   27
# f   compact      16   44
#     midsize      16   32
#     minivan      11   24
#     subcompact   16   44
# r   2seater      15   26
#     subcompact   14   26
#     suv          11   20

# %% [markdown]
# 여기까지가 agg의 공식적인 사용방법이다.

# %% [markdown]
# # 데이터프레임 합치기
# - merge
# - concat
# - join

# %%
test1 = pd.DataFrame({'id':[1,2,3,4,5],
                     'midterm':[60,80,70,90,85]})
test2 = pd.DataFrame({'id':[1,2,3,4,5],
                     'final':[70,83,65,95,80]})
print(test1)
test2
# Out:
#    id  midterm
# 0   1       60
# 1   2       80
# 2   3       70
# 3   4       90
# 4   5       85
#    id  final
# 0   1     70
# 1   2     83
# 2   3     65
# 3   4     95
# 4   5     80

# %%
pd.merge(test1, test2)  #id부분이 공통되기 때문에 잡아준다.
# Out:
#    id  midterm  final
# 0   1       60     70
# 1   2       80     83
# 2   3       70     65
# 3   4       90     95
# 4   5       85     80

# %%
test1 = pd.DataFrame({'id':[1,2,3,4,5],
                     'midterm':[60,80,70,90,85]})
test2 = pd.DataFrame({'id':[1,2,3,6,7],
                     'final':[70,83,65,95,80]})
print(test1)
test2
# Out:
#    id  midterm
# 0   1       60
# 1   2       80
# 2   3       70
# 3   4       90
# 4   5       85
#    id  final
# 0   1     70
# 1   2     83
# 2   3     65
# 3   6     95
# 4   7     80

# %%
pd.merge(test1, test2) #같은것만 보여준다.
# Out:
#    id  midterm  final
# 0   1       60     70
# 1   2       80     83
# 2   3       70     65

# %%
pd.merge(test1, test2, how = 'right') #오른쪽만 다 살린다는 뜻
# Out:
#    id  midterm  final
# 0   1     60.0     70
# 1   2     80.0     83
# 2   3     70.0     65
# 3   6      NaN     95
# 4   7      NaN     80

# %%
#total 칼럼 지우기
exam.drop('total', axis = 1, inplace = True)
exam
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [213], in <cell line: 2>()
#       1 #total 칼럼 지우기
# ----> 2 exam.drop('total', axis = 1, inplace = True)
#       3 exam
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4957, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4809 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
teacher = pd.DataFrame({'nclass':[1,2,3,4,5],
                      'teacher':['choi','park','hong','kim','jeong']})
teacher
# Out:
#    nclass teacher
# 0       1    choi
# 1       2    park
# 2       3    hong
# 3       4     kim
# 4       5   jeong

# %%
pd.merge(exam, teacher)
# Out:
#     id  nclass  math  english  science teacher
# 0    1       1    50       98       50    choi
# 1    2       1    60       97       60    choi
# 2    3       1    45       86       78    choi
# 3    4       1    30       98       58    choi
# 4    5       2    25       80       65    park
# 5    6       2    50       89       98    park
# 6    7       2    80       90       45    park
# 7    8       2    90       78       25    park
# 8    9       3    20       98       15    hong
# 9   10       3    50       98       45    hong
# 10  11       3    65       65       65    hong
# 11  12       3    45       85       32    hong
# 12  13       4    46       98       65     kim
# 13  14       4    48       87       12     kim
# 14  15       4    75       56       78     kim
# 15  16       4    58       98       65     kim
# 16  17       5    65       68       98   jeong
# 17  18       5    80       78       90   jeong
# 18  19       5    89       68       87   jeong
# ...

# %% [markdown]
# ## concat

# %%
pd.concat([test1, test2])
# Out:
#    id  midterm  final
# 0   1     60.0    NaN
# 1   2     80.0    NaN
# 2   3     70.0    NaN
# 3   4     90.0    NaN
# 4   5     85.0    NaN
# 0   1      NaN   70.0
# 1   2      NaN   83.0
# 2   3      NaN   65.0
# 3   6      NaN   95.0
# 4   7      NaN   80.0

# %%
pd.concat([test1, test2], axis = 1)  #인덱스 기준으로 그냥 붙여버린다.
# Out:
#    id  midterm  id  final
# 0   1       60   1     70
# 1   2       80   2     83
# 2   3       70   3     65
# 3   4       90   6     95
# 4   5       85   7     80

# %% [markdown]
# ```
# - set_index()
# - reset_index()
# - reindex()
# ```

# %%
test2.reindex([3,4,5,6,7])
# Out:
#     id  final
# 3  6.0   95.0
# 4  7.0   80.0
# 5  NaN    NaN
# 6  NaN    NaN
# 7  NaN    NaN

# %%
pd.concat([test1,test2], axis = 1, join = 'inner')
# Out:
#    id  midterm  id  final
# 0   1       60   1     70
# 1   2       80   2     83
# 2   3       70   3     65
# 3   4       90   6     95
# 4   5       85   7     80

# %%
test3 = test2.rename({'final':'midterm'}, axis = 1)
test3
# Out:
#    id  midterm
# 0   1       70
# 1   2       83
# 2   3       65
# 3   6       95
# 4   7       80

# %% [markdown]
# id 별로 midterm의 평균은?

# %%
group = pd.concat([test1, test3])
group
# Out:
#    id  midterm
# 0   1       60
# 1   2       80
# 2   3       70
# 3   4       90
# 4   5       85
# 0   1       70
# 1   2       83
# 2   3       65
# 3   6       95
# 4   7       80

# %%
group.groupby('id').mean() #어짜피 칼럼이 1개여서 뒤에 안 적어줌
# Out:
#     midterm
# id
# 1      65.0
# 2      81.5
# 3      67.5
# 4      90.0
# 5      85.0
# 6      95.0
# 7      80.0

# %%
group.groupby('id').agg(mean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [230], in <cell line: 1>()
# ----> 1 group.groupby('id').agg(mean)
#
# NameError: name 'mean' is not defined

# %% [markdown]
# .mean()는 내장함수가 아니다. groupby 매소드로 존재하는 mean이고
#
# .agg(mean)은 내장함수가 아니기 때문에 오류가 발생한다.
#
# 오류 발생을 막으려면 .agg(np.mean)이라고 입력하면 된다.

# %%
import numpy as np
group.groupby('id').agg(np.mean)
# Out:
#     midterm
# id
# 1      65.0
# 2      81.5
# 3      67.5
# 4      90.0
# 5      85.0
# 6      95.0
# 7      80.0

# %% [markdown]
# # 결측치

# %% [markdown]
# ## 결측치 만들기

# %%
exam.iloc[0,2] = np.nan
exam.iloc[1,3] = np.nan
exam.iloc[2,4] = np.nan
exam[:5]
# Out:
#    id  nclass  math  english  science
# 0   1       1   NaN     98.0     50.0
# 1   2       1  60.0      NaN     60.0
# 2   3       1  45.0     86.0      NaN
# 3   4       1  30.0     98.0     58.0
# 4   5       2  25.0     80.0     65.0

# %% [markdown]
# ## 결측치 확인하기

# %%
# 복제하기
df = exam.copy()
pd.isna(df)
# Out:
#        id  nclass   math  english  science
# 0   False   False   True    False    False
# 1   False   False  False     True    False
# 2   False   False  False    False     True
# 3   False   False  False    False    False
# 4   False   False  False    False    False
# 5   False   False  False    False    False
# 6   False   False  False    False    False
# 7   False   False  False    False    False
# 8   False   False  False    False    False
# 9   False   False  False    False    False
# 10  False   False  False    False    False
# 11  False   False  False    False    False
# 12  False   False  False    False    False
# 13  False   False  False    False    False
# 14  False   False  False    False    False
# 15  False   False  False    False    False
# 16  False   False  False    False    False
# 17  False   False  False    False    False
# 18  False   False  False    False    False
# 19  False   False  False    False    False

# %%
pd.isna(df).sum()  #개수를 보여준다
# Out:
# id         0
# nclass     0
# math       1
# english    1
# science    1
# dtype: int64

# %% [markdown]
# ## 결측치 제거하기

# %%
df.dropna()  # 인덱스 보면 1,2 사라짐. NA를 지워버림
# Out:
#     id  nclass  math  english  science
# 3    4       1  30.0     98.0     58.0
# 4    5       2  25.0     80.0     65.0
# 5    6       2  50.0     89.0     98.0
# 6    7       2  80.0     90.0     45.0
# 7    8       2  90.0     78.0     25.0
# 8    9       3  20.0     98.0     15.0
# 9   10       3  50.0     98.0     45.0
# 10  11       3  65.0     65.0     65.0
# 11  12       3  45.0     85.0     32.0
# 12  13       4  46.0     98.0     65.0
# 13  14       4  48.0     87.0     12.0
# 14  15       4  75.0     56.0     78.0
# 15  16       4  58.0     98.0     65.0
# 16  17       5  65.0     68.0     98.0
# 17  18       5  80.0     78.0     90.0
# 18  19       5  89.0     68.0     87.0
# 19  20       5  78.0     83.0     58.0

# %%
df   #하지만 저장하지 않았기 때문에 출력물에서만 지워짐
# Out:
#     id  nclass  math  english  science
# 0    1       1   NaN     98.0     50.0
# 1    2       1  60.0      NaN     60.0
# 2    3       1  45.0     86.0      NaN
# 3    4       1  30.0     98.0     58.0
# 4    5       2  25.0     80.0     65.0
# 5    6       2  50.0     89.0     98.0
# 6    7       2  80.0     90.0     45.0
# 7    8       2  90.0     78.0     25.0
# 8    9       3  20.0     98.0     15.0
# 9   10       3  50.0     98.0     45.0
# 10  11       3  65.0     65.0     65.0
# 11  12       3  45.0     85.0     32.0
# 12  13       4  46.0     98.0     65.0
# 13  14       4  48.0     87.0     12.0
# 14  15       4  75.0     56.0     78.0
# 15  16       4  58.0     98.0     65.0
# 16  17       5  65.0     68.0     98.0
# 17  18       5  80.0     78.0     90.0
# 18  19       5  89.0     68.0     87.0
# 19  20       5  78.0     83.0     58.0

# %%
df.dropna(subset = 'math')   # math 칼럼에 있던 NA가 사라졌다.
# Out:
#     id  nclass  math  english  science
# 1    2       1  60.0      NaN     60.0
# 2    3       1  45.0     86.0      NaN
# 3    4       1  30.0     98.0     58.0
# 4    5       2  25.0     80.0     65.0
# 5    6       2  50.0     89.0     98.0
# 6    7       2  80.0     90.0     45.0
# 7    8       2  90.0     78.0     25.0
# 8    9       3  20.0     98.0     15.0
# 9   10       3  50.0     98.0     45.0
# 10  11       3  65.0     65.0     65.0
# 11  12       3  45.0     85.0     32.0
# 12  13       4  46.0     98.0     65.0
# 13  14       4  48.0     87.0     12.0
# 14  15       4  75.0     56.0     78.0
# 15  16       4  58.0     98.0     65.0
# 16  17       5  65.0     68.0     98.0
# 17  18       5  80.0     78.0     90.0
# 18  19       5  89.0     68.0     87.0
# 19  20       5  78.0     83.0     58.0

# %%
df['math'].mean() #이게 정석 모양
# Out:
# 57.8421052631579

# %%
np.mean(df.math)
# Out:
# 57.8421052631579

# %%
df.apply(np.mean)
# Out:
# id         10.500000
# nclass      3.000000
# math       57.842105
# english    84.263158
# science    58.473684
# dtype: float64

# %% [markdown]
# ## 결측치 대체하기

# %%
m = df['math'].mean()
m
# Out:
# 57.8421052631579

# %%
df['math'] = df['math'].fillna(m)
df
# Out:
#     id  nclass       math  english  science
# 0    1       1  57.842105     98.0     50.0
# 1    2       1  60.000000      NaN     60.0
# 2    3       1  45.000000     86.0      NaN
# 3    4       1  30.000000     98.0     58.0
# 4    5       2  25.000000     80.0     65.0
# 5    6       2  50.000000     89.0     98.0
# 6    7       2  80.000000     90.0     45.0
# 7    8       2  90.000000     78.0     25.0
# 8    9       3  20.000000     98.0     15.0
# 9   10       3  50.000000     98.0     45.0
# 10  11       3  65.000000     65.0     65.0
# 11  12       3  45.000000     85.0     32.0
# 12  13       4  46.000000     98.0     65.0
# 13  14       4  48.000000     87.0     12.0
# 14  15       4  75.000000     56.0     78.0
# 15  16       4  58.000000     98.0     65.0
# 16  17       5  65.000000     68.0     98.0
# 17  18       5  80.000000     78.0     90.0
# 18  19       5  89.000000     68.0     87.0
# 19  20       5  78.000000     83.0     58.0

# %%
df['english'].fillna(method='bfill', inplace = True)
df
# Out:
#     id  nclass       math  english  science
# 0    1       1  57.842105     98.0     50.0
# 1    2       1  60.000000     86.0     60.0
# 2    3       1  45.000000     86.0      NaN
# 3    4       1  30.000000     98.0     58.0
# 4    5       2  25.000000     80.0     65.0
# 5    6       2  50.000000     89.0     98.0
# 6    7       2  80.000000     90.0     45.0
# 7    8       2  90.000000     78.0     25.0
# 8    9       3  20.000000     98.0     15.0
# 9   10       3  50.000000     98.0     45.0
# 10  11       3  65.000000     65.0     65.0
# 11  12       3  45.000000     85.0     32.0
# 12  13       4  46.000000     98.0     65.0
# 13  14       4  48.000000     87.0     12.0
# 14  15       4  75.000000     56.0     78.0
# 15  16       4  58.000000     98.0     65.0
# 16  17       5  65.000000     68.0     98.0
# 17  18       5  80.000000     78.0     90.0
# 18  19       5  89.000000     68.0     87.0
# 19  20       5  78.000000     83.0     58.0

# %%
s = df['science'].mean()
df['science'].fillna(s, inplace = True) 
df
# Out:
#     id  nclass       math  english    science
# 0    1       1  57.842105     98.0  50.000000
# 1    2       1  60.000000     86.0  60.000000
# 2    3       1  45.000000     86.0  58.473684
# 3    4       1  30.000000     98.0  58.000000
# 4    5       2  25.000000     80.0  65.000000
# 5    6       2  50.000000     89.0  98.000000
# 6    7       2  80.000000     90.0  45.000000
# 7    8       2  90.000000     78.0  25.000000
# 8    9       3  20.000000     98.0  15.000000
# 9   10       3  50.000000     98.0  45.000000
# 10  11       3  65.000000     65.0  65.000000
# 11  12       3  45.000000     85.0  32.000000
# 12  13       4  46.000000     98.0  65.000000
# 13  14       4  48.000000     87.0  12.000000
# 14  15       4  75.000000     56.0  78.000000
# 15  16       4  58.000000     98.0  65.000000
# 16  17       5  65.000000     68.0  98.000000
# 17  18       5  80.000000     78.0  90.000000
# 18  19       5  89.000000     68.0  87.000000
# ...

# %% [markdown]
# # 이상치

# %% [markdown]
# ## 이상치 존재

# %%
df.iloc[0,2] = 10
df.iloc[1,3] = 10
df[:3]
# Out:
#    id  nclass  math  english    science
# 0   1       1   NaN     98.0  50.000000
# 1   2       1  60.0     10.0  60.000000
# 2   3       1  45.0     86.0  58.473684

# %%
sns.boxplot(data = df, y = 'english') #점이 이상치
# Out:
# <AxesSubplot:ylabel='english'>
