# %% [markdown]
# # 크롤링
# : 소프트웨어 등이 웹을 돌아다니며 유용한 정보를 찾아 특정 데이터베이스로 수집해 오는 작업을 뜻한다.

# %% [markdown]
# ## 순서
# ```
# 1.원하는 웹 페이지의 주소 및 html구조 파악 ( 웹페이지에서 개발자도구 - F12 를 눌러 구조 파악)
#
# 2.requests 로 웹페이지의 html 정보 수집
#
# 3.BeautifulSoup 으로 html구조 분석
# ```

# %% [markdown]
# ## import

# %%
import urllib.request
from bs4 import BeautifulSoup
from urllib import request # 소스코드를 받아오기 위함

# %% [markdown]
# ## 원하는 것만 뽑기

# %%
url = "https://search.naver.com/search.naver?where=news&sm=tab_jum&query=%EC%9A%B0%ED%81%AC%EB%9D%BC%EC%9D%B4%EB%82%98"

# %%
html = request.urlopen(url).read()
html
# Out:
# b'<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="\xec\x9a\xb0\xed\x81\xac\xeb\x9d\xbc\xec\x9d\xb4\xeb\x82\x98 : \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\x89\xb4\xec\x8a\xa4\xea\xb2\x80\xec\x83\x89"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'\xec\x9a\xb0\xed\x81\xac\xeb\x9d\xbc\xec\x9d\xb4\xeb\x82\x98\'\xec\x9d\x98 \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\x89\xb4\xec\x8a\xa4\xea\xb2\x80\xec\x83\x89 \xea\xb2\xb0\xea\xb3\xbc\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa4."> <meta name="description" lang="ko" content="\'\xec\x9a\xb0\xed\x81\xac\xeb\x9d\xbc\xec\x9d\xb4\xeb\x82\x98\'\xec\x9d\x98 \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\x89\xb4\xec\x8a\xa4
# ...

# %% [markdown]
# ```
# request : 요청
# response : 응답
# 요청과 응답을 쉽게 해주는게 requests 라이브러리이다.
#
# ```

# %% [markdown]
# ```
# HTML은 웹페이지를 보여줄 때 사용하는 언어이다.
# 즉, 문서인걸 표시한다.
# ```

# %% [markdown]
# ## BeautifulSoup

# %% [markdown]
# ```
# < BeautifulSoup가 필요한 이유 >
#
# request.text를 이용해 가져온 데이터는 텍스트형태의 html 입니다.
# 텍스트형태의 데이터에서 원하는 html 태그를 추출을 쉽게 할 수 있도록 도와준다.
# ```

# %%
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# ```
# 괄호 안에 있는 html 위치는 파싱할 문서이고, 'html.parser'는 파싱 방식이다.
# ```

# %% [markdown]
# ```
# lxml은 구문을 분석하기 위한 파서이다.
#
# response.text로 가져온 String은 lxml이라는 모듈의 해석에 의하여
# 의미있는 HTML 문서로 변환되고, 이렇게 변환된 HTML문서는 BeautifulSoup에 의해서
# 원하는 부분을 탐색할 수 있게 된다.
#
# 그래서 보통 BeautifulSoup이랑 lxml이랑 같이 쓴다.
# ```

# %%
soup.find_all(class_ = "news_tit")
# find_all() 다 찾겠다라는 함수
# find만 쓰면 딱 한개만 보여준다.
# Out:
# [<a class="news_tit" href="http://www.womennews.co.kr/news/articleView.html?idxno=229198" onclick="return goOtherCR(this, 'a=nws*a.tit&amp;r=1&amp;i=88000589_000000000000000000101145&amp;g=310.0000101145&amp;u='+urlencode(this.href));" target="_blank" title="우크라이나 헤르손 탈환 시도...가장 치열한 전투 예상"><mark>우크라이나</mark> 헤르손 탈환 시도...가장 치열한 전투 예상</a>,
#  <a class="news_tit" href="http://news.tvchosun.com/site/data/html_dir/2022/10/27/2022102790031.html" onclick="return goOtherCR(this, 'a=nws*j.tit&amp;r=5&amp;i=88156f73_000000000000000000380089&amp;g=448.0000380089&amp;u='+urlencode(this.href));" target="_blank" title="러, 푸틴 참관 대규모 핵 훈련…&quot;우크라이나 '더러운 폭탄' 우려&quot;">러, 푸틴 참관 대규모 핵 훈련…"<mark>우크라이나</mark> '더러운 폭탄' 우려"</a>,
# ...

# %% [markdown]
# ```
# find : 1개의 태그만 찾음.
# find_all : 모든 태그를 찾음.
# select_one : 1개의 태그만 찾음.
# select : 모든 태그를 찾음.
#
# find는 class_라고 쳐야 했지만
# select는 class_ 대신 .(점)을 앞에 써줘야한다.
# #샵은 id를 뜻한다.
# ```

# %%
title = soup.find_all(class_ = "news_tit")
title
# Out:
# [<a class="news_tit" href="http://www.womennews.co.kr/news/articleView.html?idxno=229198" onclick="return goOtherCR(this, 'a=nws*a.tit&amp;r=1&amp;i=88000589_000000000000000000101145&amp;g=310.0000101145&amp;u='+urlencode(this.href));" target="_blank" title="우크라이나 헤르손 탈환 시도...가장 치열한 전투 예상"><mark>우크라이나</mark> 헤르손 탈환 시도...가장 치열한 전투 예상</a>,
#  <a class="news_tit" href="http://news.tvchosun.com/site/data/html_dir/2022/10/27/2022102790031.html" onclick="return goOtherCR(this, 'a=nws*j.tit&amp;r=5&amp;i=88156f73_000000000000000000380089&amp;g=448.0000380089&amp;u='+urlencode(this.href));" target="_blank" title="러, 푸틴 참관 대규모 핵 훈련…&quot;우크라이나 '더러운 폭탄' 우려&quot;">러, 푸틴 참관 대규모 핵 훈련…"<mark>우크라이나</mark> '더러운 폭탄' 우려"</a>,
# ...

# %%
len(title)
# Out:
# 10

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
type(title)
# Out:
# bs4.element.ResultSet

# %% [markdown]
# soup와 title은 타입이 다르다.

# %%
# 원하는 기사로 뽑기
title[0].text
# Out:
# '우크라이나 헤르손 탈환 시도...가장 치열한 전투 예상'

# %% [markdown]
# ```
# 안에 있는 글자만 쏙 뽑아내었다.
#
# text 뒤에 괄호를 안붙여도 된다.
# ```

# %%
[tit.text for tit in title]
# Out:
# ['우크라이나 헤르손 탈환 시도...가장 치열한 전투 예상',
#  '러, 푸틴 참관 대규모 핵 훈련…"우크라이나 \'더러운 폭탄\' 우려"',
#  '대만, 우크라이나 재건에 약 800억원 지원키로',
#  '전쟁 피해 한국 온 우크라이나인 뇌출혈…인천시 도움으로 치료',
#  '우크라이나, 수백만 해외 피란민에 “올겨울엔 귀국 말라” 당부',
#  '우크라이나 전쟁 후 흑해 돌고래 5만 마리 떼죽음, 왜?',
#  '우주소년단, 유엔난민기구와 ‘우크라이나 난민 지원 모금’ 시작',
#  "'지구안보'의 눈으로 본 우크라이나전쟁",
#  '“감당할 수 없다, 귀국하지 마라”...혹독한 겨울 대비 나선 우크라이나',
#  '“유럽 천연가스, 우크라이나 전쟁 이전 수준으로 회귀”']

# %%
# 이렇게 하면 링크가 뜨는데 링크만 추출하려면?
title[0]
# Out:
# <a class="news_tit" href="http://www.womennews.co.kr/news/articleView.html?idxno=229198" onclick="return goOtherCR(this, 'a=nws*a.tit&amp;r=1&amp;i=88000589_000000000000000000101145&amp;g=310.0000101145&amp;u='+urlencode(this.href));" target="_blank" title="우크라이나 헤르손 탈환 시도...가장 치열한 전투 예상"><mark>우크라이나</mark> 헤르손 탈환 시도...가장 치열한 전투 예상</a>

# %%
title[0].attrs['href'] # 속성의 이름이 href이다. 라는 뜻
# Out:
# 'http://www.womennews.co.kr/news/articleView.html?idxno=229198'

# %%
for i in title:
    print(i.text, " : ", i.attrs['href'])
# Out:
# 우크라이나 헤르손 탈환 시도...가장 치열한 전투 예상  :  http://www.womennews.co.kr/news/articleView.html?idxno=229198
# 러, 푸틴 참관 대규모 핵 훈련…"우크라이나 '더러운 폭탄' 우려"  :  http://news.tvchosun.com/site/data/html_dir/2022/10/27/2022102790031.html
# 대만, 우크라이나 재건에 약 800억원 지원키로  :  https://www.yna.co.kr/view/AKR20221027058900009?input=1195m
# 전쟁 피해 한국 온 우크라이나인 뇌출혈…인천시 도움으로 치료  :  http://www.newsis.com/view/?id=NISX20221026_0002062855&cID=14001&pID=14000
# 우크라이나, 수백만 해외 피란민에 “올겨울엔 귀국 말라” 당부  :  https://news.kbs.co.kr/news/view.do?ncd=5587218&ref=A
# 우크라이나 전쟁 후 흑해 돌고래 5만 마리 떼죽음, 왜?  :  https://view.asiae.co.kr/article/2022102614482734312
# 우주소년단, 유엔난민기구와 ‘우크라이나 난민 지원 모금’ 시작  :  https://idsn.co.kr/news/view/1065593497597345
# '지구안보'의 눈으로 본 우크라이나전쟁  :  https://www.pressian.com/pages/articles/2022102616183903030?utm_source=naver&utm_medium=search
# “감당할 수 없다, 귀국하지 마라”...혹독한 겨울 대비 나선 우크라이나  :  https://www.khan.co.kr/world/europe-russia/article/202210261512001
# ...

# %% [markdown]
# ## User-Agent
# "난 침입자(기계)가 아니에요!"

# %% [markdown]
# - 이유

# %%
from bs4 import BeautifulSoup
from urllib import request
import urllib.request

url = 'https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q=%ED%94%84%EB%9E%91%EC%8A%A4'
html = request.urlopen(url).read()
soup = BeautifulSoup(html, 'lxml')
title = soup.find_all(class_ = "news_tit")

len(title)
# Out:
# 0

# %% [markdown]
# 출력 결과 길이는 0으로 나온다. 왜일까?

# %%
soup = BeautifulSoup(html, 'lxml')
soup
# Out:
# <html><head><script type="text/javascript">
# location.replace( "https://ncaptcha.search.daum.net/captcha/show?redirect=http%3A%2F%2Fsearch.daum.net%2Fsearch%3Fw%3Dnews%26nil_search%3Dbtn%26DA%3DNTB%26enc%3Dutf8%26cluster%3Dy%26cluster_page%3D1%26q%3D%25ED%2594%2584%25EB%259E%2591%25EC%258A%25A4" );
# </script>
# </head></html>

# %% [markdown]
# ```
# 출력결과는 여러개가 나와야하는데 위와 같이 나왔다.
# 왜 이렇게 출력 되었을까?
#
# 정보를 긁어오려는 서버에서 사용자인지, 침입자인지(로봇입니까?) 구별하기 위해
# 자신의 서버에서 가져오는걸 막는다.
#
# 웹 브라우저로 접근하기 위해서는 user agent로 접근해야 하는데
# 구글에 user agent 라고 검색하면 손쉽게 찾을 수 있다.
# ```

# %% [markdown]
# ```
# user agent를 붙여넣는 과정은 다음과 같다.
# (html = request.urlopen(url).read() 이렇게 다가가는건 이제 의미 없으니 제거하기)
# ```

# %%
import requests

url = 'https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q=%EB%AF%B8%EA%B5%AD'
header = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36"}

html = requests.get(url, headers = header).text
html #출력값을 보니 정상적으로 가져왔다.
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<!doctype html>\n<html xmlns="http://www.w3.org/1999/xhtml" lang="ko" class="win chrome">\n<head profile="http://a9.com/-/spec/opensearch/1.1/">\n<meta http-equiv="content-Type" content="text/html;charset=utf-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n<meta name="autocomplete" content="off" />\n<meta name="referrer" content="always">\n<meta name="format-detection" content="telephone=no" />\n<meta property="og:title" content="미국 &ndash; Daum 검색" />\n<meta property="og:url" content="https://search.daum.net/search?w=news&q=%EB%AF%B8%EA%B5%AD" />\n<meta property="og:description" content="Daum 검색에서 미국에 대한 최신정보를 찾아보세요." />\n<meta property="og:image" content="https://search1.daumcdn.net/search/statics/common/img/og_search.png" />\n<meta property="og:site_name" content="다음검색" />\n<title>미국 &ndash; Daum 검색</title>\n<link rel="search" type="application/opensearchdescription+xml" href="//search.daum.net/OpenSearch.xml" title=
# ...

# %% [markdown]
# ```
# <GET 요청할 때 parameter 전달법>
#
# 파라미터를 딕셔너리 형식으로 정리하고 requests 모듈에 던져주는 것
# ```

# %%
soup = BeautifulSoup(html, 'lxml') 
soup
# Out:
# <!DOCTYPE html>
# <html class="win chrome" lang="ko" xmlns="http://www.w3.org/1999/xhtml">
# <head profile="http://a9.com/-/spec/opensearch/1.1/">
# <meta content="text/html;charset=utf-8" http-equiv="content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="off" name="autocomplete"/>
# <meta content="always" name="referrer"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="미국 – Daum 검색" property="og:title"/>
# <meta content="https://search.daum.net/search?w=news&amp;q=%EB%AF%B8%EA%B5%AD" property="og:url"/>
# <meta content="Daum 검색에서 미국에 대한 최신정보를 찾아보세요." property="og:description"/>
# <meta content="https://search1.daumcdn.net/search/statics/common/img/og_search.png" property="og:image"/>
# <meta content="다음검색" property="og:site_name"/>
# <title>미국 – Daum 검색</title>
# <link href="//search.daum.net/OpenSearch.xml" rel="search" title="Daum" type="application/opensearchdescription+xml"/>
# ...

# %%
title = soup.find_all(class_ = "tit_main") # 클래스는 다음 기준
title
# Out:
# [<a class="tit_main fn_tit_u" href="http://v.media.daum.net/v/20221027030804141?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26ZjRU0I2onpjDloLe&amp;pg=1&amp;r=1&amp;p=4&amp;rc=10&amp;e1=16bOiOx4gG2S18EPLj&amp;e3=0&amp;ext=dsid=26ZjRU0I2onpjDloLe", event, {"cpid": {"value": "16bOiOx4gG2S18EPLj"}});' target="_blank"><b>미국</b> 합작회사 설립해 기업금융 역량 확대</a>,
#  <a class="tit_main fn_tit_u" href="http://v.media.daum.net/v/20221027134200041?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26QTi3sqnSMwBOtYMd&amp;pg=1&amp;r=2&amp;p=4&amp;rc=10&amp;e1=16O8sbGdUflWYlfqu4&amp;e3=0&amp;ext=dsid=26QTi3sqnSMwBOtYMd", event, {"cpid": {"value": "16O8sbGdUflWYlfqu4"}});' target="_blank"><b>미국</b> 중간선거 이민에 어떤 영향 미치나</a>,
# ...

# %% [markdown]
# "tit_main" 찾는 방법은 오른쪽 눌러서 '검사' 누르기 커서 대고 class 부분 찾기

# %%
len(title)
# Out:
# 10

# %% [markdown]
# 정상적으로 10개가 보이게 된다.

# %%
for i in title:
    print(i.text)
# Out:
# 미국 합작회사 설립해 기업금융 역량 확대
# 미국 중간선거 이민에 어떤 영향 미치나
# “한국에서 미국 주립대 학위 받아요.”
# 미국, 세계화 반대로 돌아서다
# 상하이, 미국 압박 속 반도체 인력 훈련 캠퍼스 잇달아 신설
# 미국서 주목받는 신예 작곡가, 김빛나
# 중국 학자 "미국, 대만과 밀착하면 중국과 관계 단절될 수도"
# 캐나다가 먼저 금리인상 속도조절 나섰다…미국도 추종할까?
# "中 인터넷 댓글부대 미국 중간선거 개입 시도" WSJ
# 블룸버그 “시진핑 미국 추월 시점 2049년으로 제시”

# %% [markdown]
# ## select 사용

# %% [markdown]
# ```
# 만약 select를 사용하려 하는데 변수에 띄어쓰기가 있을 경우에는
# (예를 들어 'tit_main fn_tit_u') 띄어쓰기에 .을 추가하면 된다.
#
# 여기서 .은 빈공간이라는 뜻이다.
# ```

# %%
title = soup.select(".tit_main")
title # 잘 작동되는것을 볼 수 있다.
# Out:
# [<a class="tit_main fn_tit_u" href="http://v.media.daum.net/v/20221027030804141?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26ZjRU0I2onpjDloLe&amp;pg=1&amp;r=1&amp;p=4&amp;rc=10&amp;e1=16bOiOx4gG2S18EPLj&amp;e3=0&amp;ext=dsid=26ZjRU0I2onpjDloLe", event, {"cpid": {"value": "16bOiOx4gG2S18EPLj"}});' target="_blank"><b>미국</b> 합작회사 설립해 기업금융 역량 확대</a>,
#  <a class="tit_main fn_tit_u" href="http://v.media.daum.net/v/20221027134200041?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26QTi3sqnSMwBOtYMd&amp;pg=1&amp;r=2&amp;p=4&amp;rc=10&amp;e1=16O8sbGdUflWYlfqu4&amp;e3=0&amp;ext=dsid=26QTi3sqnSMwBOtYMd", event, {"cpid": {"value": "16O8sbGdUflWYlfqu4"}});' target="_blank"><b>미국</b> 중간선거 이민에 어떤 영향 미치나</a>,
# ...

# %%
title = soup.select("#newsColl > div.cont_divider > ul > li:nth-child(1) > div.wrap_cont > a")
title
# Out:
# [<a class="tit_main fn_tit_u" href="http://v.media.daum.net/v/20221027030804141?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26ZjRU0I2onpjDloLe&amp;pg=1&amp;r=1&amp;p=4&amp;rc=10&amp;e1=16bOiOx4gG2S18EPLj&amp;e3=0&amp;ext=dsid=26ZjRU0I2onpjDloLe", event, {"cpid": {"value": "16bOiOx4gG2S18EPLj"}});' target="_blank"><b>미국</b> 합작회사 설립해 기업금융 역량 확대</a>]

# %% [markdown]
# ```
# [ 검사 -> copy -> selector 순으로 눌렀다. ]
#
# 클래스 찾으려고 애를 쓸 필요가 없이 이렇게 하면 나온다.
# ```

# %% [markdown]
# # 뉴스 페이지 최소 코드 정리

# %%
url = 'https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q=%EB%AF%B8%EA%B5%AD'
header = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36"}

html = requests.get(url, headers = header).text
soup = BeautifulSoup(html, 'html.parser')
title = soup.find_all(class_ = "tit_main")

for i in title:
    print(i.text)
# Out:
# 미국 합작회사 설립해 기업금융 역량 확대
# 미국 중간선거 이민에 어떤 영향 미치나
# “한국에서 미국 주립대 학위 받아요.”
# 미국, 세계화 반대로 돌아서다
# 상하이, 미국 압박 속 반도체 인력 훈련 캠퍼스 잇달아 신설
# 미국서 주목받는 신예 작곡가, 김빛나
# 중국 학자 "미국, 대만과 밀착하면 중국과 관계 단절될 수도"
# 캐나다가 먼저 금리인상 속도조절 나섰다…미국도 추종할까?
# "中 인터넷 댓글부대 미국 중간선거 개입 시도" WSJ
# 블룸버그 “시진핑 미국 추월 시점 2049년으로 제시”

# %%
url1 = 'https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q=%EB%AF%B8%EA%B5%AD&p=10'
header = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36"}

soup = BeautifulSoup(html, 'html.parser')
title = soup.find_all(class_ = "tit_main")

for j in range(1,11):
    url = url1 + str(j)  # i는 숫자여서 문자열로 바꿔줌
    html = requests.get(url, headers = header).text
    soup = BeautifulSoup(html, 'html.parser')
    title = soup.find_all(class_ = "tit_main")
    
    for i in title:
        print(i.text, ": ", i.attrs['href'])
    print(f"{j} 페이지 입니다.")
    print("-" * 20)
# Out:
# 거창군, ‘농특산식품 미국 온·오프라인 안테나숍’ 운영 :  https://cp.news.search.daum.net/p/124961588
# [브릿지 칼럼] 중국이 미국을 추월할 수 있을까 :  https://cp.news.search.daum.net/p/124822310
# 미국, 코로나 하위변위 확산..올 겨울 재확산 경고 :  http://v.media.daum.net/v/20221016154902567?f=o
# SK지오센트릭, 이번에 미국 기업과 손잡고 재활용 공장 설립 :  http://v.media.daum.net/v/20221027113014365?f=o
# 물가 상승, 금리 인상에 따른 미국 자동차 판매 시장 변화 :  https://cp.news.search.daum.net/p/124771877
# 사우디, 미국 보란듯 친중원미…"中, 믿을만한 석유 파트너" :  http://v.media.daum.net/v/20221026174245257?f=o
# 미국 집값, 두 달 연속 하락..2009년 이후 최대폭↓ :  http://v.media.daum.net/v/20221026004639957?f=o
# 중국 극초음속 미사일에 놀란 미국.."미국 업체 기술이 넘어갔다" :  http://v.media.daum.net/v/20221018192010650?f=o
# 킹달러는 미국이 얻고 있는 '우크라 전쟁 프리미엄'이다? :  http://v.media.daum.net/v/20221025175510416?f=o
# 필리핀, 미국 눈치봤나..러시아제 헬기 대신 미국산 구매 추진 :  http://v.media.daum.net/v/20221021111630351?f=o
# 1 페이지 입니다.
# --------------------
# 미국 민주당 내부에서도 우크라이나 전쟁 휴전 요구 목소리 나와 :  https://cp.news.search.daum.net/p/124902477
# ...

# %% [markdown]
# # input 사용

# %% [markdown]
# - 구조

# %%
url1 = 'https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q='
url2 = 검색어
url3 = "&p=" -> 페이지 번호

# %%
url1 = 'https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q='
url2 = input('검색어를 입력해 주세요: ')
url3 = "&p=" 

url = url1 + url2 + url3 + str(1)
url
# Out:
# 검색어를 입력해 주세요:  우크라이나
# 'https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q=우크라이나&p=1'

# %%
url2 = input('검색어를 입력해 주세요: ')
for j in range(1,3):
    url1 = 'https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q='
    url3 = "&p=" 
    url = url1 + url2 + url3 + str(j)
    
    html = requests.get(url, headers = header).text
    soup = BeautifulSoup(html, 'html.parser')
    title = soup.find_all(class_ = "tit_main")
    for i in title:
        print(i.text, ": ", i.attrs['href'])
    print(f"{j} 페이지 입니다.")
    print("-" * 20)
    print()
# Out:
# 검색어를 입력해 주세요:  네이버
# "엎친데 덮친 격" 카카오·네이버 실적 성장세 꺾였나 :  http://v.media.daum.net/v/20221027063013123?f=o
# [더벨][플랫폼 상생전략 점검]네이버웹툰, PPS로 일군 창작자 생태계 :  https://cp.news.search.daum.net/p/124973522
# 글로벌 빅테크 실적 `쇼크`…네이버·카카오도 전망 `흐림` :  http://v.media.daum.net/v/20221027165713053?f=o
# 카카오·네이버, 시장전망치 하회 예상…"경기침체로 광고둔화" :  http://v.media.daum.net/v/20221027163602081?f=o
# '네카오'로 묶이는 먹통 사태, 네이버에 불똥 튀나 :  https://cp.news.search.daum.net/p/124981763
# NIA, 네이버·쉘파스페이스와 말레이시아 스마트팜 구축 :  http://v.media.daum.net/v/20221027134622198?f=o
# 네이버클라우드, NIA ‘국제IT협력프로젝트’에 클라우드 인프라 지원 :  http://v.media.daum.net/v/20221027141009056?f=o
# 엠에이치앤코, 킨드릴코리아 IT 서비스 통해 네이버클라우드로 인프라 이전 :  https://cp.news.search.daum.net/p/124981267
# 강연하는 추영민 네이버 교육센터 리더 :  https://cp.news.search.daum.net/p/124988809
# 네이버·카카오서 ‘차보험’ 추천될까…보험업계와 줄다리기[보험톡톡] :  https://cp.news.search.daum.net/p/124986985
# 1 페이지 입니다.
# --------------------
#
# 올프리 아기 물티슈, 네이버 쇼핑BEST 1위 :  http://v.media.daum.net/v/20221027153508099?f=o
# ...

# %% [markdown]
# # def 함수 사용
# : input 보다 좀 더 상위버전이다.

# %%
from urllib import request
from bs4 import BeautifulSoup
import requests

url1 = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query='
url3 = '&sort=0&photo=0&field=0&pd=0&ds=&de=&cluster_rank=31&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:all,a:all'
url4 = '&start='

def search_naver(url2):
    for i in range(1, 11):
        url = url1 + url2 + url3 + url4 + str(i)
        html = requests.get(url).text
        soup = BeautifulSoup(html, 'html.parser')
        title = soup.find_all(class_ = 'news_tit')
        for j in title:
            print(j.text, ':', j.attrs['href'])
        print(f'{i}페이지입니다.')
        print('-' * 100)

# %%
search_naver('바다')
# Out:
# 경기바다 특화 '김' 시험 재배…수온변화 적합한 품종 개발 추진 : https://www.yna.co.kr/view/AKR20221027052300061?input=1195m
# "따뜻한 남쪽 바다에서 온 해양생물을 소개합니다" : http://www.newsis.com/view/?id=NISX20221027_0002063151&cID=13001&pID=13000
# '시화 MTV 디아티크' 28일 선보여…"바다와 공원을 즐기는 힐링 라이프" : http://www.wowtv.co.kr/NewsCenter/News/Read?articleId=A202210270150&t=NN
# 경기바다 특화 '김' 시험 재배…경기도, 수온변화 적합한 품종 개발 추진 : https://www.sedaily.com/NewsView/26CIIEITK2
# 코소모스 바다 : https://www.news1.kr/photos/view/?5652172
# [단풍 캘박 특집] 구름다리 건너 단풍 바다 속으로 : http://san.chosun.com/news/articleView.html?idxno=21896
# [기고/원정혜]우리가 바다로 가는 이유 : https://www.donga.com/news/article/all/20221027/116186258/1
# 삼척시, 제16회 삼척시장배 전국바다낚시대회 개최 : https://www.ajunews.com/view/20221027155312042
# [사회이슈] 세븐일레븐, 바다 환경 지키기 위한 플로깅 활동 진행 外 : http://www.lawissue.co.kr/view.php?ud=202210270951019604204ead0791_12
# ‘안개·이슬의 바다’ 가로림만, 갯벌 복원해 생태 보고로 거듭난다 : https://www.hani.co.kr/arti/area/chungcheong/1064502.html
# 1페이지입니다.
# ...

# %% [markdown]
# # 출력물 저장하기

# %%
import pandas as pd

def search_naver(word):
    li1 = []
    li2 = []
    
    for i in range(1, 11):
        url = url1 + word + url3 + url4 + str(i)
        html = requests.get(url).text
        soup = BeautifulSoup(html, 'html.parser')
        title = soup.find_all(class_ = 'news_tit')
        for j in title:
            li1.append(j.text)
            li2.append(j.attrs['href'])
        data = pd.DataFrame({"제목": li1, "링크": li2})
        data.to_csv(f"{word}.csv") #판다스로 저장하기
        
        return data

# %%
search_naver('바다')
# Out:
#                                            제목  \
# 0         경기바다 특화 '김' 시험 재배…수온변화 적합한 품종 개발 추진
# 1                 "따뜻한 남쪽 바다에서 온 해양생물을 소개합니다"
# 2  '시화 MTV 디아티크' 28일 선보여…"바다와 공원을 즐기는 힐링 라이프"
# 3                 삼척시, 제16회 삼척시장배 전국바다낚시대회 개최
# 4                                     코소모스 바다
# 5                [단풍 캘박 특집] 구름다리 건너 단풍 바다 속으로
# 6                       [기고/원정혜]우리가 바다로 가는 이유
# 7    경기바다 특화 '김' 시험 재배…경기도, 수온변화 적합한 품종 개발 추진
# 8      [사회이슈] 세븐일레븐, 바다 환경 지키기 위한 플로깅 활동 진행 外
# 9                새만금, 숲과 바다가 어우러진 해양관광지로 개발된다
#
#                                                   링크
# 0  https://www.yna.co.kr/view/AKR2022102705230006...
# 1  http://www.newsis.com/view/?id=NISX20221027_00...
# 2  http://www.wowtv.co.kr/NewsCenter/News/Read?ar...
# 3     https://www.ajunews.com/view/20221027155312042
# 4          https://www.news1.kr/photos/view/?5652172
# 5  http://san.chosun.com/news/articleView.html?id...
# 6  https://www.donga.com/news/article/all/2022102...
# ...

# %%
res = requests.get(url)

# %%
res.status_code
# Out:
# 200

# %% [markdown]
# ```
# 상태 코드라고 한다.
# 검색창에 상태 코드 정리라고 치면 나온다.
#
# 200은 잘 처리가 되었다는 뜻
# ```

# %% [markdown]
# # 이미지 저장하기

# %%
from bs4 import BeautifulSoup
from urllib import request
import urllib.request

url = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query=%EB%B0%94%EB%8B%A4'

html = requests.get(url).text
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
images = soup.find_all(class_ = '_image _listImage') # 이미지를 나타내는 클래스를 잡아주면 된다.
images
# Out:
# []

# %% [markdown]
# ```
# 위의 결과를 보니 출력되지 않았다.
#
# 설명에 앞서 웹페이지의 구성을 알아야한다.
# 웹페이지는 HTML 문서로 작성되어 있다.
# 그리고 이 문서에는 인터페이스를 참조할 수 있는 CSS파일과
# 페이지 상호작용을 위한 JavaScript 파일을 참조할 수 있다.
# 이렇게 되면 우리는 모든 웹페이지의 HTML문서를 확인 할 수 있게 된다.
#
# 그럼 이제 본론으로 돌아와서,
# 아까 우리는 header을 이용하여 침입자가 아니라고 증명을 하고 통과했다.
# 그래서 원하는 코드를 가지고 나갔지만 출력이 되지 않는다.
#
# 이는 서버의 자바스크립트가 가지고 나가려는 코드를
# 안에서 마음대로 이름을 지어버려서 준다.
# 즉, 서버에서 보여주는 진짜 서버 코드와 내가 받은 코드는 다르다는 뜻이다.
#
# 이걸 확인하는 방법은 ctrl + f 해서 아까 위에서 만든_image _listImage을
# 검색해서 나오는지 보면 된다.
#
# 어떻게 하면 받을 수 있는가?
# 실제 웹브라우져로 접근해야지 제대로 받을 수 있다.
# 그래서 나온게 selenium와 chromedriver게 필요하다.
# ```

# %% [markdown]
# ## selenium
# ```
# - pip install selenium
# - 스크래파이, lxml, 뷰티풀 숲 등의 다른 라이브러리가 하지 못하는
#     동적할당페이지를 유일하게 크롤링 할 수 있다.
# - 동적할당페이지란?
#     페이지를 웹상에서 클릭했을 때 코드가 전혀 보이지 않는 구조를 갖고 있는 페이지
#     하지만 셀리니움은 속도면에서 새로운 페이지를 띄워야 하니 느리다.
# ```

# %% [markdown]
# ## chromedriver
# ```
# - chromedriver는 내 크롬의 버전과 맞아야하기 때문에
#     위에 점 3개 누르고 도움말 들어가면 크롬의 버전을 볼 수 있다.
#
# - 스테이블이고 win32 버전으로 받기
# ```

# %%
import selenium
from selenium import webdriver

# %% [markdown]
# - < 검색 용어가 영어일 경우 >

# %%
driver = webdriver.Chrome('C://Users//admin/chromedriver.exe')

# %% [markdown]
# - < 검색 용어가 한글일 경우 >

# %%
driver = webdriver.Chrome('C://Users//admin/chromedriver.exe')

url1 = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query='
url2 = quote_plus('바다')  #quo는 한글을 처리해주는 함수
url = url1 + url2

driver.get(url)
html = driver.page_source
driver.close()

soup = BeautifulSoup(html, 'html.parser')
images = soup.find_all(class_ = '_image _listImage')

count = 0
for image in images:
    urlretrieve(image['src'], f'./sea/{count}.jpg') # 저장 위치
    count += 1
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8956\2831824175.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C://Users//admin/chromedriver.exe')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [50], in <cell line: 4>()
#       1 driver = webdriver.Chrome('C://Users//admin/chromedriver.exe')
#       3 url1 = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query='
# ----> 4 url2 = quote_plus('바다')  #quo는 한글을 처리해주는 함수
#       5 url = url1 + url2
#       7 driver.get(url)
#
# NameError: name 'quote_plus' is not defined

# %% [markdown]
# 그런데 무작정 실행하면 안된다!!!!

# %% [markdown]
# ## 주의

# %% [markdown]
# ```
# driver을 다룰때 한 셀에 다 넣어서 실행시키면 문제가 발생할 수 있다.
# 실행 속도가 빠르기 때문에 받아 오기도 전에 close가 될 수도 있다.
#
# 지금 이 코드도 실행시키면 에러는 뜨지 않지만 지정한 폴더에는 아무것도 저장되어 있지 않다.
# ```

# %% [markdown]
# ```
# 드라이브를 텀을 두고 실행시키는 방법
# 1. time.sleep 2. driver.implicitly_wait()
# ```

# %% [markdown]
# ### time.sleep

# %%
import time

driver = webdriver.Chrome('C://Users//admin/chromedriver.exe')

url1 = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query='
url2 = quote_plus('바다')  #quo는 한글을 처리해주는 함수
url = url1 + url2

driver.get(url)
time.sleep(10)

html = driver.page_source
driver.close()

soup = BeautifulSoup(html, 'html.parser')
images = soup.find_all(class_ = '_image _listImage')

count = 0
for image in images:
    urlretrieve(image['src'], f'./sea/{count}.jpg') # 저장 위치
    count += 1
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8956\967977350.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C://Users//admin/chromedriver.exe')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [49], in <cell line: 6>()
#       3 driver = webdriver.Chrome('C://Users//admin/chromedriver.exe')
#       5 url1 = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query='
# ----> 6 url2 = quote_plus('바다')  #quo는 한글을 처리해주는 함수
#       7 url = url1 + url2
#       9 driver.get(url)
#
# NameError: name 'quote_plus' is not defined

# %% [markdown]
# ### driver.implicitly_wait()

# %%
driver = webdriver.Chrome('C://Users//admin/chromedriver.exe')

url1 = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query='
url2 = quote_plus('강아지')  #quo는 한글을 처리해주는 함수
url = url1 + url2

driver.get(url)
driver.implicitly_wait(10)

html = driver.page_source
driver.close()

soup = BeautifulSoup(html, 'html.parser')
images = soup.find_all(class_ = '_image _listImage')

count = 0
for image in images:
    urlretrieve(image['src'], f'./sea/{count}.jpg') # 저장 위치
    count += 1

# %% [markdown]
# 암묵적으로 10초를 기다리는데 데이터를 다 받으면 10초 다 기다리지 않는다.
