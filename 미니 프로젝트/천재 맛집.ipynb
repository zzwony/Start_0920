# %% [markdown]
# # 맛집

# %% [markdown]
# ## 필요 라이브러리

# %%
import requests
from bs4 import BeautifulSoup
import selenium
from selenium import webdriver
from urllib.request import urlopen, urlretrieve
from urllib.parse import quote_plus
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
import os
os.getcwd()
os.chdir('C:\\Users\\admin')

# %%
driver = webdriver.Chrome('chromedriver.exe')
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_10876\530843676.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')

# %% [markdown]
# ## 맛집 찾기

# %%
url = "https://map.naver.com/"
driver.get(url)

# %%
location = input('위치를 입력하세요: ')
xpath = '/html/body/app/layout/div[3]/div[2]/shrinkable-layout/div/app-base/search-input-box/div/div/div/input'
search = driver.find_element(By.XPATH, xpath)
search.clear()
search.send_keys(f'{location} 맛집')
search.send_keys(Keys.ENTER)
# Out:
# 위치를 입력하세요:  이대

# %% [markdown]
# ## 식당 이름 따기

# %%
driver.switch_to.frame('searchIframe')

# %%
import datetime
import time

def doScrollDown(whileSeconds):
    start = datetime.datetime.now()
    end = start + datetime.timedelta(seconds=whileSeconds)
    while True:
        scroll = driver.find_element(By.XPATH, '/html/body/div[3]/div/div[2]/div[1]')
        driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scroll)
        time.sleep(1)
        if datetime.datetime.now() > end:
            break

# %%
doScrollDown(5)

# %%
rec = driver.find_elements(By.CLASS_NAME, 'place_bluelink.TYaxT')

li2 = []
for i in range(0, len(rec)):
    li2.append(rec[i].text)

# li2

# %%
len(li2)
# Out:
# 54

# %% [markdown]
# ## 전체 텍스트 따기

# %%
rec = driver.find_elements(By.CLASS_NAME, 'UEzoS.rTjJo')

lists = []
for i in range(0, len(rec)):
    lists.append(rec[i].text)

# lists

# %%
len(lists)
# Out:
# 54

# %%
driver.switch_to.parent_frame()

# %%
# driver.close()

# %% [markdown]
# ## \n 없애기

# %%
import re

# %%
for i in range(0, len(lists)):
    p = re.compile(r'\n')
    lists[i] = p.sub(' ', lists[i])
# lists

# %% [markdown]
# ## 리뷰 뽑기 + 빈칸 0으로 바꾸기 + 리스트 하나로 만들기

# %%
ind = []
for i in range(0, len(lists)):
    a = re.compile(r'\d\.\d{2}')
    ind.append(a.findall(lists[i]))
    for i in range(0, len(ind)):
        if ind[i] == []:
            ind[i] = '0'
            
# reviews1 = [item for sublist in ind for item in sublist][2:22]
# reviews2 = [item for sublist in ind for item in sublist][24:]
# reviews = reviews1 + reviews2
reviews = [item for sublist in ind for item in sublist]

# %%
reviews
# Out:
# ['4.82',
#  '0',
#  '4.65',
#  '4.67',
#  '4.61',
#  '0',
#  '0',
#  '4.51',
#  '4.58',
#  '4.52',
#  '4.58',
#  '0',
#  '4.41',
#  '4.67',
#  '4.63',
#  '4.47',
#  '4.82',
#  '4.46',
#  '4.57',
#  '4.41',
#  '4.63',
#  '4.84',
#  '4.91',
#  '4.64',
#  '4.49',
#  '4.56',
#  '4.36',
#  '4.72',
#  '4.57',
#  '4.44',
#  '0',
#  '4.56',
#  '4.45',
#  '0',
#  '0',
#  '4.46',
#  '4.62',
#  '4.49',
#  '4.27',
#  '0',
#  '4.48',
#  '4.37',
#  '4.83',
#  '0',
#  '4.59',
#  '4.42',
#  '4.66',
#  '4.61',
#  '4.33',
#  '4.72',
#  '4.32',
#  '0',
#  '4.28',
#  '0']

# %% [markdown]
# ## 데이터 프레임 만들기

# %%
import pandas as pd

# %%
df = pd.DataFrame(zip(li2, reviews), columns=['식당이름', '별점'])

# %%
df
# Out:
#                식당이름    별점
# 0                아건  4.82
# 1              피자클럽     0
# 2              하늘초밥  4.65
# 3              연어초밥  4.67
# 4          위샐러듀 이대점  4.61
# 5          마더린러 베이글     0
# 6                목란     0
# 7        티앙팡 오후의 홍차  4.51
# 8             유야케도쿄  4.58
# 9               고냉지  4.52
# 10          오르랔베이커리  4.58
# 11       쏠페스타 이화여대점     0
# 12               비밀  4.41
# 13             비아37  4.67
# 14     사장님돈까스 이화여대점  4.63
# 15             원즈오운  4.47
# 16               아건  4.82
# 17       삭 수제튀김 전문점  4.46
# 18            에이테이블  4.57
# 19             란주탕슉  4.41
# 20     waffle it up  4.63
# 21             진돈부리  4.84
# 22         디저트바 이브흐  4.91
# 23           메이크베이크  4.64
# 24          미스터서왕만두  4.49
# 25             까이식당  4.56
# 26     방콕익스프레스 신촌본점  4.36
# 27        그릭데이 이대본점  4.72
# 28            카우떡볶이  4.57
# 29           공릉닭한마리  4.44
# 30             아콘스톨     0
# 31           파파노다이닝  4.56
# 32              도꼭지  4.45
# 33             카페페라     0
# 34      연희동 라이라이 본점     0
# 35           두끼 이대점  4.46
# 36              호밀밭  4.62
# 37        어바웃샤브 이대점  4.49
# 38          밀리네해물잡탕  4.27
# 39      에그 앤드 스푼레이스     0
# 40           스탠바이키친  4.48
# 41         옥루몽 신촌본점  4.37
# 42          굿바이슈가베어  4.83
# 43       모센즈스위트 이대점     0
# 44                유  4.59
# 45           로드샌드위치  4.42
# 46               희게  4.66
# 47              참참참  4.61
# 48              내사랑  4.33
# 49  커피도가 헤리티지 신촌이대점  4.72
# 50        연희동칼국수 본점  4.32
# 51       고스트요거트 이대점     0
# 52   김광석신촌칼국수 이대직영점  4.28
# 53              유소바     0

# %%
df.iloc[24:, :]
# Out:
#                식당이름    별점
# 24          미스터서왕만두  4.49
# 25             까이식당  4.56
# 26     방콕익스프레스 신촌본점  4.36
# 27        그릭데이 이대본점  4.72
# 28            카우떡볶이  4.57
# 29           공릉닭한마리  4.44
# 30             아콘스톨     0
# 31           파파노다이닝  4.56
# 32              도꼭지  4.45
# 33             카페페라     0
# 34      연희동 라이라이 본점     0
# 35           두끼 이대점  4.46
# 36              호밀밭  4.62
# 37        어바웃샤브 이대점  4.49
# 38          밀리네해물잡탕  4.27
# 39      에그 앤드 스푼레이스     0
# 40           스탠바이키친  4.48
# 41         옥루몽 신촌본점  4.37
# 42          굿바이슈가베어  4.83
# 43       모센즈스위트 이대점     0
# 44                유  4.59
# 45           로드샌드위치  4.42
# 46               희게  4.66
# 47              참참참  4.61
# 48              내사랑  4.33
# 49  커피도가 헤리티지 신촌이대점  4.72
# 50        연희동칼국수 본점  4.32
# 51       고스트요거트 이대점     0
# 52   김광석신촌칼국수 이대직영점  4.28
# 53              유소바     0

# %%
no1 = df.iloc[2:22, :]
no2 = df.iloc[24:, :]
frames = [no1, no2]
f_df = pd.concat(frames)
f_df.reset_index(drop=True, inplace=True)
f_df
# Out:
#                식당이름    별점
# 0              하늘초밥  4.65
# 1              연어초밥  4.67
# 2          위샐러듀 이대점  4.61
# 3          마더린러 베이글     0
# 4                목란     0
# 5        티앙팡 오후의 홍차  4.51
# 6             유야케도쿄  4.58
# 7               고냉지  4.52
# 8           오르랔베이커리  4.58
# 9        쏠페스타 이화여대점     0
# 10               비밀  4.41
# 11             비아37  4.67
# 12     사장님돈까스 이화여대점  4.63
# 13             원즈오운  4.47
# 14               아건  4.82
# 15       삭 수제튀김 전문점  4.46
# 16            에이테이블  4.57
# 17             란주탕슉  4.41
# 18     waffle it up  4.63
# 19             진돈부리  4.84
# 20          미스터서왕만두  4.49
# 21             까이식당  4.56
# 22     방콕익스프레스 신촌본점  4.36
# 23        그릭데이 이대본점  4.72
# 24            카우떡볶이  4.57
# 25           공릉닭한마리  4.44
# 26             아콘스톨     0
# 27           파파노다이닝  4.56
# 28              도꼭지  4.45
# 29             카페페라     0
# 30      연희동 라이라이 본점     0
# 31           두끼 이대점  4.46
# 32              호밀밭  4.62
# 33        어바웃샤브 이대점  4.49
# 34          밀리네해물잡탕  4.27
# 35      에그 앤드 스푼레이스     0
# 36           스탠바이키친  4.48
# 37         옥루몽 신촌본점  4.37
# 38          굿바이슈가베어  4.83
# 39       모센즈스위트 이대점     0
# 40                유  4.59
# 41           로드샌드위치  4.42
# 42               희게  4.66
# 43              참참참  4.61
# 44              내사랑  4.33
# 45  커피도가 헤리티지 신촌이대점  4.72
# 46        연희동칼국수 본점  4.32
# 47       고스트요거트 이대점     0
# 48   김광석신촌칼국수 이대직영점  4.28
# 49              유소바     0

# %% [markdown]
# ## 위도 경도 불러오기

# %% [markdown]
# ### 함수

# %%
import requests

def place_find(s) :
    # 접속 url
    url = 'http://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(s)
    
    # headers 입력
    headers = {
        # 카카오지도 접속
        "Authorization" : "KakaoAK de2ab0f4e5f24304ac7898b7de2cacd8"
    }
    # API 요청
    places = requests.get(url, headers=headers).json()['documents']
    try :
        places = places[0]
        df1_name  = places['place_name']
        위도 = places['y']
        경도 = places['x']
        
        result = [df1_name, 위도, 경도]
        
        return result
    except:
        pass

# %%
correct = []
for i in range(len(f_df)):
    correct.append(location + " " + f_df.iloc[i].식당이름)

correct_location = pd.DataFrame (correct, columns = ['식당이름'])
correct_location
# Out:
#                   식당이름
# 0              이대 진돈부리
# 1           이대 굿바이슈가베어
# 2                이대 아건
# 3   이대 커피도가 헤리티지 신촌이대점
# 4         이대 그릭데이 이대본점
# 5              이대 비아37
# 6              이대 연어초밥
# 7                이대 희게
# 8              이대 하늘초밥
# 9      이대 waffle it up
# 10     이대 사장님돈까스 이화여대점
# 11              이대 호밀밭
# 12              이대 참참참
# 13         이대 위샐러듀 이대점
# 14                이대 유
# 15          이대 오르랔베이커리
# 16            이대 유야케도쿄
# 17            이대 에이테이블
# 18            이대 카우떡볶이
# 19           이대 파파노다이닝
# 20             이대 까이식당
# 21              이대 고냉지
# 22       이대 티앙팡 오후의 홍차
# 23          이대 미스터서왕만두
# 24        이대 어바웃샤브 이대점
# 25           이대 스탠바이키친
# 26             이대 원즈오운
# 27           이대 두끼 이대점
# 28       이대 삭 수제튀김 전문점
# 29              이대 도꼭지
# 30           이대 공릉닭한마리
# 31           이대 로드샌드위치
# 32               이대 비밀
# 33             이대 란주탕슉
# 34         이대 옥루몽 신촌본점
# 35     이대 방콕익스프레스 신촌본점
# 36              이대 내사랑
# 37        이대 연희동칼국수 본점
# 38   이대 김광석신촌칼국수 이대직영점
# 39          이대 밀리네해물잡탕
# 40               이대 목란
# 41       이대 고스트요거트 이대점
# 42         이대 마더린러 베이글
# 43      이대 연희동 라이라이 본점
# 44       이대 쏠페스타 이화여대점
# 45             이대 카페페라
# 46       이대 모센즈스위트 이대점
# 47      이대 에그 앤드 스푼레이스
# 48             이대 아콘스톨
# 49              이대 유소바

# %%
# 테스트
place_find(correct_location['식당이름'][0])
# Out:
# ['진돈부리', '37.5569534052124', '126.942456981822']

# %% [markdown]
# ### 위도 경도 받기

# %%
# 위경도 가져오기
food_place_list = []

for i in correct_location['식당이름']:
    data = place_find(i)
    food_place_list.append(data)

# %%
food_place_list
# Out:
# [['진돈부리', '37.5569534052124', '126.942456981822'],
#  ['굿바이슈가베어', '37.5594402689244', '126.944573787447'],
#  ['아건 이대점', '37.55906291657092', '126.94492718486593'],
#  None,
#  None,
#  ['비아37', '37.5589904689193', '126.944144041557'],
#  ['연어초밥', '37.5570648016113', '126.941972390604'],
#  ['희게', '37.568663448725', '126.931908543177'],
#  ['하늘초밥', '37.5573085850893', '126.94669402413'],
#  ['와플잇업 이대2호점', '37.5582476571318', '126.943325190362'],
#  None,
#  ['호밀밭', '37.558918423412536', '126.94052464390788'],
#  ['참참참', '37.5594592726059', '126.944750333255'],
#  ['위샐러듀 이대점', '37.5594592641306', '126.944732224555'],
#  ['중식당 유', '37.5589547990805', '126.944931791588'],
#  ['오르랔베이커리', '37.5574463401982', '126.952816767662'],
#  ['유야케도쿄', '37.5580425967736', '126.944094951109'],
#  ['에이테이블', '37.56539833179252', '126.95230693236766'],
#  ['카우떡볶이', '37.5595742224795', '126.943948936902'],
#  ['파파노다이닝', '37.5594193347522', '126.944125612718'],
#  ['까이식당', '37.55838957093877', '126.94622922509853'],
#  ['고냉지', '37.5584921906342', '126.942215861247'],
#  ['티앙팡 오후에 홍차 1호점', '37.55841652340589', '126.94605943897574'],
#  ['미스터서왕만두', '37.55802773012356', '126.94315106397343'],
#  ['어바웃샤브 이대점', '37.5586525369446', '126.945955144903'],
#  ['스탠바이키친', '37.56456065275251', '126.94461753264709'],
#  ['원즈오운', '37.55773622939119', '126.9459693879222'],
#  ['두끼떡볶이 이대점', '37.55899192384859', '126.9434151696065'],
#  None,
#  None,
#  ['공릉닭한마리', '37.55712571563', '126.941076103559'],
#  ['로드샌드위치', '37.56437676610759', '126.94443996542006'],
#  ['비밀', '37.5585538958815', '126.943116710815'],
#  ['란주탕슉', '37.5581661536053', '126.94629502857'],
#  ['옥루몽 신촌본점', '37.563383440636', '126.943538615883'],
#  ['방콕익스프레스 신촌본점', '37.557169356192', '126.941868300831'],
#  ['내사랑', '37.5575181878461', '126.947975032553'],
#  ['연희동칼국수 본점', '37.5682239892832', '126.930748718394'],
#  ['김광석신촌칼국수 이대직영점', '37.558862329259', '126.940065183752'],
#  ['밀리네해물잡탕', '37.5561770571336', '126.946970975817'],
#  ['목란', '37.56838240474039', '126.93047690875805'],
#  ['고스트요거트 이대점', '37.5593403960735', '126.944868127434'],
#  ['마더린러베이글', '37.558309895691', '126.945384976896'],
#  None,
#  None,
#  ['카페페라 유니크점', '37.5594595570187', '126.94536150187854'],
#  ['모센즈스위트 이대점', '37.5588018388745', '126.945382354266'],
#  ['에그앤드스푼레이스', '37.557978612048', '126.946000902517'],
#  ['아콘스톨', '37.5583787734025', '126.942437777275'],
#  ['유소바', '37.5572551849175', '126.946162134593']]

# %%
# None을 []으로 바꾸기
for i in range(0, len(food_place_list)):
    if food_place_list[i] is None:
        food_place_list[i] = []

# %%
# food_place_list

# %% [markdown]
# ### 별점이랑 합치기

# %%
for i in range(0, len(food_place_list)):
    if food_place_list[i] == []:
        continue
    else:
        food_place_list[i].append(f_df.iloc[i].별점)
        
food_place_list
# Out:
# [['진돈부리', '37.5569534052124', '126.942456981822', '4.84'],
#  ['굿바이슈가베어', '37.5594402689244', '126.944573787447', '4.83'],
#  ['아건 이대점', '37.55906291657092', '126.94492718486593', '4.82'],
#  [],
#  [],
#  ['비아37', '37.5589904689193', '126.944144041557', '4.67'],
#  ['연어초밥', '37.5570648016113', '126.941972390604', '4.67'],
#  ['희게', '37.568663448725', '126.931908543177', '4.66'],
#  ['하늘초밥', '37.5573085850893', '126.94669402413', '4.65'],
#  ['와플잇업 이대2호점', '37.5582476571318', '126.943325190362', '4.63'],
#  [],
#  ['호밀밭', '37.558918423412536', '126.94052464390788', '4.62'],
#  ['참참참', '37.5594592726059', '126.944750333255', '4.61'],
#  ['위샐러듀 이대점', '37.5594592641306', '126.944732224555', '4.61'],
#  ['중식당 유', '37.5589547990805', '126.944931791588', '4.59'],
#  ['오르랔베이커리', '37.5574463401982', '126.952816767662', '4.58'],
#  ['유야케도쿄', '37.5580425967736', '126.944094951109', '4.58'],
#  ['에이테이블', '37.56539833179252', '126.95230693236766', '4.57'],
#  ['카우떡볶이', '37.5595742224795', '126.943948936902', '4.57'],
#  ['파파노다이닝', '37.5594193347522', '126.944125612718', '4.56'],
#  ['까이식당', '37.55838957093877', '126.94622922509853', '4.56'],
#  ['고냉지', '37.5584921906342', '126.942215861247', '4.52'],
#  ['티앙팡 오후에 홍차 1호점', '37.55841652340589', '126.94605943897574', '4.51'],
#  ['미스터서왕만두', '37.55802773012356', '126.94315106397343', '4.49'],
#  ['어바웃샤브 이대점', '37.5586525369446', '126.945955144903', '4.49'],
#  ['스탠바이키친', '37.56456065275251', '126.94461753264709', '4.48'],
#  ['원즈오운', '37.55773622939119', '126.9459693879222', '4.47'],
#  ['두끼떡볶이 이대점', '37.55899192384859', '126.9434151696065', '4.46'],
#  [],
#  [],
#  ['공릉닭한마리', '37.55712571563', '126.941076103559', '4.44'],
#  ['로드샌드위치', '37.56437676610759', '126.94443996542006', '4.42'],
#  ['비밀', '37.5585538958815', '126.943116710815', '4.41'],
#  ['란주탕슉', '37.5581661536053', '126.94629502857', '4.41'],
#  ['옥루몽 신촌본점', '37.563383440636', '126.943538615883', '4.37'],
#  ['방콕익스프레스 신촌본점', '37.557169356192', '126.941868300831', '4.36'],
#  ['내사랑', '37.5575181878461', '126.947975032553', '4.33'],
#  ['연희동칼국수 본점', '37.5682239892832', '126.930748718394', '4.32'],
#  ['김광석신촌칼국수 이대직영점', '37.558862329259', '126.940065183752', '4.28'],
#  ['밀리네해물잡탕', '37.5561770571336', '126.946970975817', '4.27'],
#  ['목란', '37.56838240474039', '126.93047690875805', '0'],
#  ['고스트요거트 이대점', '37.5593403960735', '126.944868127434', '0'],
#  ['마더린러베이글', '37.558309895691', '126.945384976896', '0'],
#  [],
#  [],
#  ['카페페라 유니크점', '37.5594595570187', '126.94536150187854', '0'],
#  ['모센즈스위트 이대점', '37.5588018388745', '126.945382354266', '0'],
#  ['에그앤드스푼레이스', '37.557978612048', '126.946000902517', '0'],
#  ['아콘스톨', '37.5583787734025', '126.942437777275', '0'],
#  ['유소바', '37.5572551849175', '126.946162134593', '0']]

# %% [markdown]
# ### 데이터 프레임 만들기

# %%
# 복사
food_place_list_1 = food_place_list
# None 값 삭제
food_place_list_1 =  [x for x in food_place_list_1 if x is not None]
# 확인
food_place_list_1

food_place = pd.DataFrame(food_place_list)
# 컬럼 명 지정해주기
food_place.columns = ['place_name', '위도', '경도', '별점']
food_place
# Out:
#         place_name                  위도                  경도    별점
# 0             진돈부리    37.5569534052124    126.942456981822  4.84
# 1          굿바이슈가베어    37.5594402689244    126.944573787447  4.83
# 2           아건 이대점   37.55906291657092  126.94492718486593  4.82
# 3             None                None                None  None
# 4             None                None                None  None
# 5             비아37    37.5589904689193    126.944144041557  4.67
# 6             연어초밥    37.5570648016113    126.941972390604  4.67
# 7               희게     37.568663448725    126.931908543177  4.66
# 8             하늘초밥    37.5573085850893     126.94669402413  4.65
# 9       와플잇업 이대2호점    37.5582476571318    126.943325190362  4.63
# 10            None                None                None  None
# 11             호밀밭  37.558918423412536  126.94052464390788  4.62
# 12             참참참    37.5594592726059    126.944750333255  4.61
# 13        위샐러듀 이대점    37.5594592641306    126.944732224555  4.61
# 14           중식당 유    37.5589547990805    126.944931791588  4.59
# 15         오르랔베이커리    37.5574463401982    126.952816767662  4.58
# 16           유야케도쿄    37.5580425967736    126.944094951109  4.58
# 17           에이테이블   37.56539833179252  126.95230693236766  4.57
# 18           카우떡볶이    37.5595742224795    126.943948936902  4.57
# 19          파파노다이닝    37.5594193347522    126.944125612718  4.56
# 20            까이식당   37.55838957093877  126.94622922509853  4.56
# 21             고냉지    37.5584921906342    126.942215861247  4.52
# 22  티앙팡 오후에 홍차 1호점   37.55841652340589  126.94605943897574  4.51
# 23         미스터서왕만두   37.55802773012356  126.94315106397343  4.49
# 24       어바웃샤브 이대점    37.5586525369446    126.945955144903  4.49
# 25          스탠바이키친   37.56456065275251  126.94461753264709  4.48
# 26            원즈오운   37.55773622939119   126.9459693879222  4.47
# 27       두끼떡볶이 이대점   37.55899192384859   126.9434151696065  4.46
# 28            None                None                None  None
# 29            None                None                None  None
# 30          공릉닭한마리      37.55712571563    126.941076103559  4.44
# 31          로드샌드위치   37.56437676610759  126.94443996542006  4.42
# 32              비밀    37.5585538958815    126.943116710815  4.41
# 33            란주탕슉    37.5581661536053     126.94629502857  4.41
# 34        옥루몽 신촌본점     37.563383440636    126.943538615883  4.37
# 35    방콕익스프레스 신촌본점     37.557169356192    126.941868300831  4.36
# 36             내사랑    37.5575181878461    126.947975032553  4.33
# 37       연희동칼국수 본점    37.5682239892832    126.930748718394  4.32
# 38  김광석신촌칼국수 이대직영점     37.558862329259    126.940065183752  4.28
# 39         밀리네해물잡탕    37.5561770571336    126.946970975817  4.27
# 40              목란   37.56838240474039  126.93047690875805     0
# 41      고스트요거트 이대점    37.5593403960735    126.944868127434     0
# 42         마더린러베이글     37.558309895691    126.945384976896     0
# 43            None                None                None  None
# 44            None                None                None  None
# 45       카페페라 유니크점    37.5594595570187  126.94536150187854     0
# 46      모센즈스위트 이대점    37.5588018388745    126.945382354266     0
# 47       에그앤드스푼레이스     37.557978612048    126.946000902517     0
# 48            아콘스톨    37.5583787734025    126.942437777275     0
# 49             유소바    37.5572551849175    126.946162134593     0

# %% [markdown]
# ## 링크 따기

# %%
link = "https://map.naver.com/"
driver.get(link)

# %%
xpath = '/html/body/app/layout/div[3]/div[2]/shrinkable-layout/div/app-base/search-input-box/div/div/div/input'
search = driver.find_element(By.XPATH, xpath)
search.clear()
search.send_keys(f'{location} 맛집')
search.send_keys(Keys.ENTER)
driver.implicitly_wait(10)

# %%
driver.switch_to.frame('searchIframe')

# %%
import datetime
import time

def doScrollDown(whileSeconds):
    start = datetime.datetime.now()
    end = start + datetime.timedelta(seconds=whileSeconds)
    while True:
        scroll = driver.find_element(By.XPATH, '/html/body/div[3]/div/div[2]/div[1]')
        driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scroll)
        time.sleep(1)
        if datetime.datetime.now() > end:
            break

# %%
doScrollDown(5)

# %%
url = driver.current_url
resp = requests.get(url)

e = driver.find_elements(By.CLASS_NAME, 'place_bluelink.TYaxT')
c = []
for i in range(2, 22):
    e[i].click()
    url = driver.current_url
    c.append(url)

d = []
for i in range(24, 54):
    e[i].click()
    url = driver.current_url
    d.append(url)

# %%
x = c+d

# %%
len(x)
# Out:
# 50

# %%
# driver.close()

# %%
food_place['link'] = x

# %%
food_place
# Out:
#         place_name                  위도                  경도    별점  \
# 0             진돈부리    37.5569534052124    126.942456981822  4.84
# 1          굿바이슈가베어    37.5594402689244    126.944573787447  4.83
# 2           아건 이대점   37.55906291657092  126.94492718486593  4.82
# 3             None                None                None  None
# 4             None                None                None  None
# 5             비아37    37.5589904689193    126.944144041557  4.67
# 6             연어초밥    37.5570648016113    126.941972390604  4.67
# 7               희게     37.568663448725    126.931908543177  4.66
# 8             하늘초밥    37.5573085850893     126.94669402413  4.65
# 9       와플잇업 이대2호점    37.5582476571318    126.943325190362  4.63
# 10            None                None                None  None
# 11             호밀밭  37.558918423412536  126.94052464390788  4.62
# 12             참참참    37.5594592726059    126.944750333255  4.61
# 13        위샐러듀 이대점    37.5594592641306    126.944732224555  4.61
# 14           중식당 유    37.5589547990805    126.944931791588  4.59
# 15         오르랔베이커리    37.5574463401982    126.952816767662  4.58
# 16           유야케도쿄    37.5580425967736    126.944094951109  4.58
# 17           에이테이블   37.56539833179252  126.95230693236766  4.57
# 18           카우떡볶이    37.5595742224795    126.943948936902  4.57
# 19          파파노다이닝    37.5594193347522    126.944125612718  4.56
# 20            까이식당   37.55838957093877  126.94622922509853  4.56
# 21             고냉지    37.5584921906342    126.942215861247  4.52
# 22  티앙팡 오후에 홍차 1호점   37.55841652340589  126.94605943897574  4.51
# 23         미스터서왕만두   37.55802773012356  126.94315106397343  4.49
# 24       어바웃샤브 이대점    37.5586525369446    126.945955144903  4.49
# 25          스탠바이키친   37.56456065275251  126.94461753264709  4.48
# 26            원즈오운   37.55773622939119   126.9459693879222  4.47
# 27       두끼떡볶이 이대점   37.55899192384859   126.9434151696065  4.46
# 28            None                None                None  None
# 29            None                None                None  None
# 30          공릉닭한마리      37.55712571563    126.941076103559  4.44
# 31          로드샌드위치   37.56437676610759  126.94443996542006  4.42
# 32              비밀    37.5585538958815    126.943116710815  4.41
# 33            란주탕슉    37.5581661536053     126.94629502857  4.41
# 34        옥루몽 신촌본점     37.563383440636    126.943538615883  4.37
# 35    방콕익스프레스 신촌본점     37.557169356192    126.941868300831  4.36
# 36             내사랑    37.5575181878461    126.947975032553  4.33
# 37       연희동칼국수 본점    37.5682239892832    126.930748718394  4.32
# 38  김광석신촌칼국수 이대직영점     37.558862329259    126.940065183752  4.28
# 39         밀리네해물잡탕    37.5561770571336    126.946970975817  4.27
# 40              목란   37.56838240474039  126.93047690875805     0
# 41      고스트요거트 이대점    37.5593403960735    126.944868127434     0
# 42         마더린러베이글     37.558309895691    126.945384976896     0
# 43            None                None                None  None
# 44            None                None                None  None
# 45       카페페라 유니크점    37.5594595570187  126.94536150187854     0
# 46      모센즈스위트 이대점    37.5588018388745    126.945382354266     0
# 47       에그앤드스푼레이스     37.557978612048    126.946000902517     0
# 48            아콘스톨    37.5583787734025    126.942437777275     0
# 49             유소바    37.5572551849175    126.946162134593     0
#
#                                                  link
# 0   https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 1   https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 2   https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 3   https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 4   https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 5   https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 6   https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 7   https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 8   https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 9   https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 10  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 11  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 12  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 13  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 14  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 15  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 16  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 17  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 18  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 19  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 20  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 21  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 22  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 23  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 24  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 25  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 26  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 27  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 28  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 29  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 30  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 31  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 32  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 33  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 34  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 35  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 36  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 37  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 38  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 39  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 40  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 41  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 42  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 43  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 44  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 45  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 46  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 47  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 48  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 49  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...

# %% [markdown]
# ## 위치 포함한 탑10

# %%
food_place.sort_values(by=['별점'], ascending=False, inplace=True)
food_place.reset_index(drop=True, inplace=True)
food_place
# Out:
#         place_name                  위도                  경도    별점  \
# 0             진돈부리    37.5569534052124    126.942456981822  4.84
# 1          굿바이슈가베어    37.5594402689244    126.944573787447  4.83
# 2           아건 이대점   37.55906291657092  126.94492718486593  4.82
# 3             비아37    37.5589904689193    126.944144041557  4.67
# 4             연어초밥    37.5570648016113    126.941972390604  4.67
# 5               희게     37.568663448725    126.931908543177  4.66
# 6             하늘초밥    37.5573085850893     126.94669402413  4.65
# 7       와플잇업 이대2호점    37.5582476571318    126.943325190362  4.63
# 8              호밀밭  37.558918423412536  126.94052464390788  4.62
# 9         위샐러듀 이대점    37.5594592641306    126.944732224555  4.61
# 10             참참참    37.5594592726059    126.944750333255  4.61
# 11           중식당 유    37.5589547990805    126.944931791588  4.59
# 12         오르랔베이커리    37.5574463401982    126.952816767662  4.58
# 13           유야케도쿄    37.5580425967736    126.944094951109  4.58
# 14           에이테이블   37.56539833179252  126.95230693236766  4.57
# 15           카우떡볶이    37.5595742224795    126.943948936902  4.57
# 16          파파노다이닝    37.5594193347522    126.944125612718  4.56
# 17            까이식당   37.55838957093877  126.94622922509853  4.56
# 18             고냉지    37.5584921906342    126.942215861247  4.52
# 19  티앙팡 오후에 홍차 1호점   37.55841652340589  126.94605943897574  4.51
# 20       어바웃샤브 이대점    37.5586525369446    126.945955144903  4.49
# 21         미스터서왕만두   37.55802773012356  126.94315106397343  4.49
# 22          스탠바이키친   37.56456065275251  126.94461753264709  4.48
# 23            원즈오운   37.55773622939119   126.9459693879222  4.47
# 24       두끼떡볶이 이대점   37.55899192384859   126.9434151696065  4.46
# 25          공릉닭한마리      37.55712571563    126.941076103559  4.44
# 26          로드샌드위치   37.56437676610759  126.94443996542006  4.42
# 27              비밀    37.5585538958815    126.943116710815  4.41
# 28            란주탕슉    37.5581661536053     126.94629502857  4.41
# 29        옥루몽 신촌본점     37.563383440636    126.943538615883  4.37
# 30    방콕익스프레스 신촌본점     37.557169356192    126.941868300831  4.36
# 31             내사랑    37.5575181878461    126.947975032553  4.33
# 32       연희동칼국수 본점    37.5682239892832    126.930748718394  4.32
# 33  김광석신촌칼국수 이대직영점     37.558862329259    126.940065183752  4.28
# 34         밀리네해물잡탕    37.5561770571336    126.946970975817  4.27
# 35              목란   37.56838240474039  126.93047690875805     0
# 36      고스트요거트 이대점    37.5593403960735    126.944868127434     0
# 37         마더린러베이글     37.558309895691    126.945384976896     0
# 38       카페페라 유니크점    37.5594595570187  126.94536150187854     0
# 39      모센즈스위트 이대점    37.5588018388745    126.945382354266     0
# 40       에그앤드스푼레이스     37.557978612048    126.946000902517     0
# 41            아콘스톨    37.5583787734025    126.942437777275     0
# 42             유소바    37.5572551849175    126.946162134593     0
# 43            None                None                None  None
# 44            None                None                None  None
# 45            None                None                None  None
# 46            None                None                None  None
# 47            None                None                None  None
# 48            None                None                None  None
# 49            None                None                None  None
#
#                                                  link
# 0   https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 1   https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 2   https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 3   https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 4   https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 5   https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 6   https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 7   https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 8   https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 9   https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 10  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 11  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 12  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 13  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 14  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 15  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 16  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 17  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 18  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 19  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 20  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 21  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 22  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 23  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 24  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 25  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 26  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 27  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 28  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 29  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 30  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 31  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 32  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 33  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 34  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 35  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 36  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 37  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 38  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 39  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 40  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 41  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 42  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 43  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 44  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 45  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 46  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 47  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 48  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 49  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...

# %%
upper = food_place.iloc[:10, :]
upper
# Out:
#    place_name                  위도                  경도    별점  \
# 0        진돈부리    37.5569534052124    126.942456981822  4.84
# 1     굿바이슈가베어    37.5594402689244    126.944573787447  4.83
# 2      아건 이대점   37.55906291657092  126.94492718486593  4.82
# 3        비아37    37.5589904689193    126.944144041557  4.67
# 4        연어초밥    37.5570648016113    126.941972390604  4.67
# 5          희게     37.568663448725    126.931908543177  4.66
# 6        하늘초밥    37.5573085850893     126.94669402413  4.65
# 7  와플잇업 이대2호점    37.5582476571318    126.943325190362  4.63
# 8         호밀밭  37.558918423412536  126.94052464390788  4.62
# 9    위샐러듀 이대점    37.5594592641306    126.944732224555  4.61
#
#                                                 link
# 0  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 1  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 2  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 3  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 4  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 5  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 6  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 7  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 8  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...
# 9  https://map.naver.com/v5/search/%EC%9D%B4%EB%8...

# %% [markdown]
# ## 지도

# %% [markdown]
# ### from website

# %%
import requests
import pandas as pd
import numpy as np
import folium
from folium.plugins import MiniMap

# %%
locat = place_find(location)[1:]

# %%
def elec_location(region,page_num):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json'
    params = {'query': region,'page': page_num}
    headers = {"Authorization": "KakaoAK de2ab0f4e5f24304ac7898b7de2cacd8"}

    places = requests.get(url, params=params, headers=headers).json()['documents']
    total = requests.get(url, params=params, headers=headers).json()['meta']['total_count']
    return places

# %%
def elec_info(places):
    X = []
    Y = []
    stores = []
    road_address = []
    place_url = []
    ID = []
    for place in places:
        X.append(float(place['x']))
        Y.append(float(place['y']))
        stores.append(place['place_name'])
        road_address.append(place['road_address_name'])
        place_url.append(place['place_url'])
        ID.append(place['id'])

    ar = np.array([ID,stores, X, Y, road_address,place_url]).T
    df = pd.DataFrame(ar, columns = ['ID','stores', 'X', 'Y','road_address','place_url'])
    return df

# %%
def keywords(location_name):
    df = None
    for loca in location:
        for page in range(1,4):
            local_name = elec_location(loca, page)
            local_elec_info = elec_info(local_name)

            if df is None:
                df = local_elec_info
            elif local_elec_info is None:
                continue
            else:
                df = pd.concat([df, local_elec_info],join='outer', ignore_index = True)
    return df

# %%
def make_map(dfs):
    # 지도 생성하기
    m = folium.Map(location=locat,   # 기준좌표: 서울시청
                   zoom_start=15)

    # 미니맵 추가하기
    minimap = MiniMap() 
    m.add_child(minimap)

    # 마커 추가하기
    for i in range(len(dfs)):
        # 마커 생성
        folium.Marker([upper['위도'][i],upper['경도'][i]],
                  tooltip=upper['place_name'][i],
                  popup=f"<a href={upper.iloc[i].link} target='_blank'>{upper.iloc[i]['place_name']}</a>", 
                      icon=folium.Icon(color='red', icon='info-sign')).add_to(m)
    return m

# %%
df = keywords(upper['place_name'])
df = df.drop_duplicates(['ID'])
df = df.reset_index()

make_map(upper)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fcc6c2d14d0ccd504fb8f138fbe6f45c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fcc6c2d14d0ccd504fb8f138fbe6f45c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_fcc6c2d14d0ccd504fb8f138fbe6f45c = L.map(
#                 &quot;map_fcc6c2d14d0ccd504fb8f138fbe6f45c&quot;,
#                 {
#                     center: [37.562544705628845, 126.94765009467245],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d60f2dc23c4c67602c4b797696ae8813 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fcc6c2d14d0ccd504fb8f138fbe6f45c);
#
#
#             var tile_layer_4abe7f473bc00be5c7e8d8db05f3e8bf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_4b3e43c822b0b1626a04c7f8ccc18116 = new L.Control.MiniMap(
#                 tile_layer_4abe7f473bc00be5c7e8d8db05f3e8bf,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: false, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_fcc6c2d14d0ccd504fb8f138fbe6f45c.addControl(mini_map_4b3e43c822b0b1626a04c7f8ccc18116);
#
#
#             var marker_4e431d2c3b04560df17e7f8a605ab5c8 = L.marker(
#                 [37.5569534052124, 126.942456981822],
#                 {}
#             ).addTo(map_fcc6c2d14d0ccd504fb8f138fbe6f45c);
#
#
#             var icon_6d910b37f45fbc4cfa2a627626fc68f5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4e431d2c3b04560df17e7f8a605ab5c8.setIcon(icon_6d910b37f45fbc4cfa2a627626fc68f5);
#
#
#         var popup_421d6c1f613a835e5e84d584506f8324 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e5ac1a4e35489e99ca46a968591d9161 = $(`&lt;div id=&quot;html_e5ac1a4e35489e99ca46a968591d9161&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=https://map.naver.com/v5/search/%EC%9D%B4%EB%8C%80%20%EB%A7%9B%EC%A7%91?c=14127976.3289783,4517697.9652139,12,0,0,0,dh target=&#x27;_blank&#x27;&gt;진돈부리&lt;/a&gt;&lt;/div&gt;`)[0];
#             popup_421d6c1f613a835e5e84d584506f8324.setContent(html_e5ac1a4e35489e99ca46a968591d9161);
#
#
#         marker_4e431d2c3b04560df17e7f8a605ab5c8.bindPopup(popup_421d6c1f613a835e5e84d584506f8324)
#         ;
#
#
#
#
#             marker_4e431d2c3b04560df17e7f8a605ab5c8.bindTooltip(
#                 `&lt;div&gt;
#                      진돈부리
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9075454d39878bb53a547c7d874305e7 = L.marker(
#                 [37.5594402689244, 126.944573787447],
#                 {}
#             ).addTo(map_fcc6c2d14d0ccd504fb8f138fbe6f45c);
#
#
#             var icon_4c5fc6b2b15cdfb7f2deb888136f84ed = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9075454d39878bb53a547c7d874305e7.setIcon(icon_4c5fc6b2b15cdfb7f2deb888136f84ed);
#
#
#         var popup_0b18db2c021c714af0420ee317133ecc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4390c9c55da5987d4264d72eb0a3721a = $(`&lt;div id=&quot;html_4390c9c55da5987d4264d72eb0a3721a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=https://map.naver.com/v5/search/%EC%9D%B4%EB%8C%80%20%EB%A7%9B%

# %%
upper
# Out:
#      place_name                  위도                  경도    별점  \
# 0  후라토식당 여의도직영점   37.52386014762182  126.92413796018808  4.81
# 1           진주집    37.5205984955116    126.926960229824  4.75
# 2    제스트 콘래드서울점    37.5255682928589    126.926747228948  4.73
# 3        당산옛날곱창  37.535371499608544  126.90228518018989  4.65
# 4       정인면옥 본점   37.53077816623998  126.92157407940762  4.63
# 5          양키통닭   37.51366350287856  126.89276020265237  4.63
# 6     세상의모든아침펜션    36.8402024192993    129.435664801212  4.63
# 7           미츠바    37.5130059085588    126.892912709865  4.62
# 8         화목순대국  37.519269537219614  126.93150663353379  4.51
# 9     63뷔페 파빌리온   37.51981484576526   126.9401710888746  4.51
#
#                                                 link
# 0  https://map.naver.com/v5/search/%EC%98%81%EB%9...
# 1  https://map.naver.com/v5/search/%EC%98%81%EB%9...
# 2  https://map.naver.com/v5/search/%EC%98%81%EB%9...
# 3  https://map.naver.com/v5/search/%EC%98%81%EB%9...
# 4  https://map.naver.com/v5/search/%EC%98%81%EB%9...
# 5  https://map.naver.com/v5/search/%EC%98%81%EB%9...
# 6  https://map.naver.com/v5/search/%EC%98%81%EB%9...
# 7  https://map.naver.com/v5/search/%EC%98%81%EB%9...
# 8  https://map.naver.com/v5/search/%EC%98%81%EB%9...
# 9  https://map.naver.com/v5/search/%EC%98%81%EB%9...
