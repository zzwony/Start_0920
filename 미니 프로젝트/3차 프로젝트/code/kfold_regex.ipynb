# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # data

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/학원/3차 프로젝트_5팀/김예지/augmented.csv')

# %%
df
# Out:
#        Unnamed: 0                                                 문장   유형  극성  \
# 0               0              0.75%포인트 금리 인상은 1994년 이후 28년 만에 처음이다.  사실형  긍정
# 1               1  이어 ＂앞으로 전문가들과 함께 4주 단위로 상황을 재평가할 예정＂이라며 ＂그 이전이...  사실형  긍정
# 2               2  정부가 고유가 대응을 위해 7월부터 연말까지 유류세 인하 폭을 30%에서 37%까지...  사실형  긍정
# 3               3  서울시는 올해 3월 즉시 견인 유예시간 60분을 제공하겠다고 밝혔지만, 하루 만에 ...  사실형  긍정
# 4               4           익사한 자는 사다리에 태워 거꾸로 놓고 소금으로 코를 막아 가득 채운다.  사실형  긍정
# ...           ...                                                ...  ...  ..
# 66159       33077  김금희 소설가는 ＂계약서 조정이 그리 어려운가 작가를 격려한다면서 그런 문구 하나 ...  사실형  긍정
# 66160       33078  1만명이 넘는  기록한 이번 전시회는 총 77개 작품을 넥슨 사옥을 그대로 구현한 ...  사실형  긍정
# 66161       33079  1만명이 넘는 방문자수를 기록한 이번 전시회는 총 77개 작품을 넥슨 사옥을 그대로...  사실형  긍정
# 66162       33080                                           《목민심서》의   사실형  긍정
# 66163       33081                                              내용이다.  사실형  긍정
#
#        시제  확실성          label
# ...

# %%
id = list(range(66164))

# %%
df['Unnamed: 0'] = id
df.rename(columns={'Unnamed: 0': 'ID'}, inplace=True)
df
# Out:
#           ID                                                 문장   유형  극성  시제  \
# 0          0              0.75%포인트 금리 인상은 1994년 이후 28년 만에 처음이다.  사실형  긍정  현재
# 1          1  이어 ＂앞으로 전문가들과 함께 4주 단위로 상황을 재평가할 예정＂이라며 ＂그 이전이...  사실형  긍정  과거
# 2          2  정부가 고유가 대응을 위해 7월부터 연말까지 유류세 인하 폭을 30%에서 37%까지...  사실형  긍정  미래
# 3          3  서울시는 올해 3월 즉시 견인 유예시간 60분을 제공하겠다고 밝혔지만, 하루 만에 ...  사실형  긍정  과거
# 4          4           익사한 자는 사다리에 태워 거꾸로 놓고 소금으로 코를 막아 가득 채운다.  사실형  긍정  현재
# ...      ...                                                ...  ...  ..  ..
# 66159  66159  김금희 소설가는 ＂계약서 조정이 그리 어려운가 작가를 격려한다면서 그런 문구 하나 ...  사실형  긍정  과거
# 66160  66160  1만명이 넘는  기록한 이번 전시회는 총 77개 작품을 넥슨 사옥을 그대로 구현한 ...  사실형  긍정  과거
# 66161  66161  1만명이 넘는 방문자수를 기록한 이번 전시회는 총 77개 작품을 넥슨 사옥을 그대로...  사실형  긍정  과거
# 66162  66162                                           《목민심서》의   사실형  긍정  현재
# 66163  66163                                              내용이다.  사실형  긍정  현재
#
#        확실성          label
# ...

# %% [markdown]
# ## kfolds

# %%
# create splits and add column with each sentence's corresponding Kth fold
from sklearn.model_selection import StratifiedKFold

folds = StratifiedKFold(n_splits=5, random_state=42, shuffle=True)
df['kfold'] = -1
for i in range(5):
    df_idx, valid_idx = list(folds.split(df.values, df['label']))[i]    # split data to generate train and validation sets
    valid = df.iloc[valid_idx]

    df.loc[df[df.ID.isin(valid.ID) == True].index.to_list(), 'kfold'] = i
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(

# %%
df
# Out:
#                 ID                                                 문장   유형  \
# 0      TRAIN_00000              0.75%포인트 금리 인상은 1994년 이후 28년 만에 처음이다.  사실형
# 1      TRAIN_00001  이어 ＂앞으로 전문가들과 함께 4주 단위로 상황을 재평가할 예정＂이라며 ＂그 이전이...  사실형
# 2      TRAIN_00002  정부가 고유가 대응을 위해 7월부터 연말까지 유류세 인하 폭을 30%에서 37%까지...  사실형
# 3      TRAIN_00003  서울시는 올해 3월 즉시 견인 유예시간 60분을 제공하겠다고 밝혔지만, 하루 만에 ...  사실형
# 4      TRAIN_00004           익사한 자는 사다리에 태워 거꾸로 놓고 소금으로 코를 막아 가득 채운다.  사실형
# ...            ...                                                ...  ...
# 16536  TRAIN_16536  ＇신동덤＇은 ＇신비한 동물사전＇과 ＇해리 포터＇ 시리즈를 잇는 마법 어드벤처물로, ...  사실형
# 16537  TRAIN_16537  수족냉증은 어릴 때부터 심했으며 관절은 어디 한 곳이 아니고 목, 어깨, 팔꿈치, ...  사실형
# 16538  TRAIN_16538  김금희 소설가는 ＂계약서 조정이 그리 어려운가 작가를 격려한다면서 그런 문구 하나 ...  사실형
# 16539  TRAIN_16539  1만명이 넘는 방문자수를 기록한 이번 전시회는 총 77개 작품을 넥슨 사옥을 그대로...  사실형
# 16540  TRAIN_16540                                      《목민심서》의 내용이다.  사실형
#
#        극성  시제  확실성          label  kfold
# ...

# %% [markdown]
# ### testing

# %%
for tmp in range(5):
    # reset train and validation sets based on fold
    FOLD = tmp
    train = df[df["kfold"] != FOLD].reset_index(drop=True)
    valid = df[df["kfold"] == FOLD].reset_index(drop=True)

    # tokenize train and validation sets
    tokenizer = AutoTokenizer.from_pretrained('kykim/bert-kor-base')
    train_data_loader = create_data_loader(train, tokenizer, 256, 32, shuffle_=True)
    valid_data_loader = create_data_loader(valid, tokenizer, 256, 32)


    EPOCHS = 10
    model = DaconClassifier(model_path = 'kykim/bert-kor-base').to(device)
    optimizer = optim.AdamW(model.parameters(), lr= 2e-5)
    total_steps = len(train_data_loader) * EPOCHS
    scheduler = get_cosine_schedule_with_warmup(
    optimizer,
    num_warmup_steps=int(total_steps*0.1),
    num_training_steps=total_steps
    )

    loss_fn = nn.CrossEntropyLoss().to(device)
    max_acc = 0
    for epoch in range(EPOCHS):
        print('-' * 10)
        print(f'Epoch {epoch}/{EPOCHS-1}')
        print('-' * 10)
        train_acc, train_loss = train_epoch(
            model,
            train_data_loader,
            loss_fn,
            optimizer,
            device,
            scheduler,
            len(train),
            epoch,
            max_acc
        )
        validate_acc, validate_loss = validate(
            model,
            valid_data_loader,
            loss_fn,
            optimizer,
            device,
            scheduler,
            len(valid)
        )

        if validate_acc > max_acc:
            max_acc = validate_acc
            torch.save(model.state_dict(),f'./korbert_cat0_fold{FOLD}.pt')

        print(f'Train loss {train_loss} accuracy {train_acc}')
        print(f'Validate loss {validate_loss} accuracy {validate_acc}')
        print("")
        print("")

    print(f'Best accuracy {max_acc}')
    #torch.save(model.state_dict(),f'/workspace/baseline_fold0_last.pt')

# %% [markdown]
# ## regex

# %%
import re
def remove_special_characters(sentence):
    sentence = sentence.lower()
    p1 = re.compile('\n')
    sentence = p1.sub(' ', sentence)
    #sentence = p1.sub('|', sentence)

    return sentence

# !pip install soynlp emoji

import re
import emoji
from soynlp.normalizer import repeat_normalize

pattern = re.compile(f'[^ .,?!/@$%~％·∼()\x00-\x7Fㄱ-ㅣ가-힣]+')
url_pattern = re.compile(
    r'https?:\/\/(www\.)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)')

def clean(x): 
    x = pattern.sub(' ', x)
    x = emoji.replace_emoji(x, replace='') #emoji 삭제
    x = url_pattern.sub('', x)
    x = x.strip()
    x = repeat_normalize(x, num_repeats=2)

    return x
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df['sentence'] = df['문장'].map(remove_special_characters)
df['sentence'] = df['문장'].map(clean)

# %%
df
# Out:
#                 ID                                                 문장   유형  \
# 0      TRAIN_00000              0.75%포인트 금리 인상은 1994년 이후 28년 만에 처음이다.  사실형
# 1      TRAIN_00001  이어 ＂앞으로 전문가들과 함께 4주 단위로 상황을 재평가할 예정＂이라며 ＂그 이전이...  사실형
# 2      TRAIN_00002  정부가 고유가 대응을 위해 7월부터 연말까지 유류세 인하 폭을 30%에서 37%까지...  사실형
# 3      TRAIN_00003  서울시는 올해 3월 즉시 견인 유예시간 60분을 제공하겠다고 밝혔지만, 하루 만에 ...  사실형
# 4      TRAIN_00004           익사한 자는 사다리에 태워 거꾸로 놓고 소금으로 코를 막아 가득 채운다.  사실형
# ...            ...                                                ...  ...
# 16536  TRAIN_16536  ＇신동덤＇은 ＇신비한 동물사전＇과 ＇해리 포터＇ 시리즈를 잇는 마법 어드벤처물로, ...  사실형
# 16537  TRAIN_16537  수족냉증은 어릴 때부터 심했으며 관절은 어디 한 곳이 아니고 목, 어깨, 팔꿈치, ...  사실형
# 16538  TRAIN_16538  김금희 소설가는 ＂계약서 조정이 그리 어려운가 작가를 격려한다면서 그런 문구 하나 ...  사실형
# 16539  TRAIN_16539  1만명이 넘는 방문자수를 기록한 이번 전시회는 총 77개 작품을 넥슨 사옥을 그대로...  사실형
# 16540  TRAIN_16540                                      《목민심서》의 내용이다.  사실형
#
#        극성  시제  확실성          label  kfold  \
# ...

# %%
df[df['sentence'].isin(df['문장'])==False]
# Out:
#                 ID                                                 문장   유형  \
# 1      TRAIN_00001  이어 ＂앞으로 전문가들과 함께 4주 단위로 상황을 재평가할 예정＂이라며 ＂그 이전이...  사실형
# 14     TRAIN_00014  이어 ＂개별 상황에 어떻게 응대해야 할 것인지도 모호한 상황＂이라며 ＂이 같은 부분...  사실형
# 15     TRAIN_00015  사우스포게임즈가 개발한 ＇스컬＇의 경우도 지난해 부산인디커넥트 페스티벌, 글로벌인디...  사실형
# 20     TRAIN_00020  KF 등급과 유사하게 KN(P)95는 0.075㎛ 이상의 미세먼지를 95% 이상 차...  사실형
# 22     TRAIN_00022  능양군이 막 문을 나서자 김류의 부인이 나와 ＇지난 밤 꿈에 어가가 집을 나가는 것...  사실형
# ...            ...                                                ...  ...
# 16521  TRAIN_16521  KBS 가요대축제는 여자 아이돌 ＇에이핑크＇의 엔딩 장면을 중간에 끊으면서 ＇홀대＇...  사실형
# 16529  TRAIN_16529  송대호 한빛소프트 게임사업팀 PM은 ＂게임 내 인맥, 커플, 팸을 위한 전용 게시판...  사실형
# 16536  TRAIN_16536  ＇신동덤＇은 ＇신비한 동물사전＇과 ＇해리 포터＇ 시리즈를 잇는 마법 어드벤처물로, ...  사실형
# 16538  TRAIN_16538  김금희 소설가는 ＂계약서 조정이 그리 어려운가 작가를 격려한다면서 그런 문구 하나 ...  사실형
# 16540  TRAIN_16540                                      《목민심서》의 내용이다.  사실형
#
#        극성  시제 확실성         label  kfold  \
# ...
