# %%
X_features=user_clr_df[['fluctuation', 'f_커리어', 'f_소형가전', 'f_셔츠', 'f_모피피혁', 'f_시티웨어', 'f_골프용품', 'f_통신컴퓨터',
                        'f_주방가전', 'f_트래디셔널', 'f_준보석시계', 'f_디자이너', 'f_대형가전', 'f_악기', 
                        'f_보석', 'f_남성 트랜디', 'f_축산가공', 'f_남성정장','f_명품', 'Monetary', 
                        'A_Monetary_실제지출', 'B_Monetary_실제지출', 'C_Monetary_실제지출','D_Monetary_실제지출']]
X_label = user_clr_df.분기매출증가
X_features_t = test[['fluctuation', 'f_커리어', 'f_소형가전', 'f_셔츠', 'f_모피피혁', 'f_시티웨어', 'f_골프용품', 'f_통신컴퓨터',
                        'f_주방가전', 'f_트래디셔널', 'f_준보석시계', 'f_디자이너', 'f_대형가전', 'f_악기', 
                        'f_보석', 'f_남성 트랜디', 'f_축산가공', 'f_남성정장','f_명품', 'Monetary', 
                        'A_Monetary_실제지출', 'B_Monetary_실제지출', 'C_Monetary_실제지출','D_Monetary_실제지출']]

X_label_t = test.분기매출증가
